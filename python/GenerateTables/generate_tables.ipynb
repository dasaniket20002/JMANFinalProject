# %%
import pandas as pd
import numpy as np
import uuid
import random
from faker import Faker
import bcrypt
from datetime import datetime, timedelta
import os

# %%
fake = Faker()

num_users = 5000
num_projects = 50

num_projects_to_users = 5000
num_projects_to_feedback_question = 2000

num_timesheets = 10000
num_feedback_answers = 8000

# %%
def generateUsers() :
    roles = ['admin', 'user', 'manager', 'employee']
    weights = [10, 50, 20, 20]

    email_ids = []
    passwords = []
    roles_list = []
    names = []

    password = bcrypt.hashpw('org_pass_1234'.encode('utf-8'), bcrypt.gensalt()).decode('utf-8')

    # Generate and store random data for each row
    for _ in range(num_users):
        while True:
            email = fake.email()
            if email not in email_ids:
                break
        role = np.random.choice(roles, p=np.array(weights)/sum(weights))
        name = fake.name()

        email_ids.append(email)
        passwords.append(password)
        roles_list.append(role)
        names.append(name)

    # Create a DataFrame
    data = {
        'email': email_ids,
        'pass': passwords,
        'role': roles_list,
        'name': names
    }

    return data

users_df = pd.DataFrame(generateUsers())
users_df
# Out:
#                           email  \
# 0         caseholly@example.net
# 1     guerreroerika@example.com
# 2       henryturner@example.org
# 3      jacqueline00@example.org
# 4       elizabeth88@example.net
# ...                         ...
# 4995       justin55@example.org
# 4996      jessica56@example.org
# 4997      vanessa76@example.com
# 4998         zhogan@example.com
# 4999     ortizkatie@example.org
#
#                                                    pass      role  \
# 0     $2b$12$pKlOky.TMF9RmQe3.HwqyOyHCIAPTaLPxh/688q...      user
# 1     $2b$12$pKlOky.TMF9RmQe3.HwqyOyHCIAPTaLPxh/688q...      user
# 2     $2b$12$pKlOky.TMF9RmQe3.HwqyOyHCIAPTaLPxh/688q...   manager
# 3     $2b$12$pKlOky.TMF9RmQe3.HwqyOyHCIAPTaLPxh/688q...   manager
# 4     $2b$12$pKlOky.TMF9RmQe3.HwqyOyHCIAPTaLPxh/688q...  employee
# ...                                                 ...       ...
# 4995  $2b$12$pKlOky.TMF9RmQe3.HwqyOyHCIAPTaLPxh/688q...  employee
# 4996  $2b$12$pKlOky.TMF9RmQe3.HwqyOyHCIAPTaLPxh/688q...      user
# 4997  $2b$12$pKlOky.TMF9RmQe3.HwqyOyHCIAPTaLPxh/688q...   manager
# 4998  $2b$12$pKlOky.TMF9RmQe3.HwqyOyHCIAPTaLPxh/688q...      user
# 4999  $2b$12$pKlOky.TMF9RmQe3.HwqyOyHCIAPTaLPxh/688q...  employee
#
#                     name
# 0          Steven Mercer
# 1        Michael Johnson
# 2            Judy Sutton
# 3          Mario Whitney
# 4          Jeffrey Mills
# ...                  ...
# 4995           Scott Cox
# 4996        Donna Miller
# 4997        Thomas Scott
# 4998  Courtney Gallagher
# 4999     Caroline Nguyen
#
# [5000 rows x 4 columns]

# %%
def generateProjects():
    ids = []
    names = []

    for _ in range(num_projects):

        while True:
            project_id = str(uuid.uuid4())
            if project_id not in ids:
                break

        while True:
            project_name = fake.company() + " " + fake.word(ext_word_list=['Project', 'Solution', 'Initiative'])
            if project_name not in names:
                break

        ids.append(project_id)
        names.append(project_name)
    
    data = {
        'id': ids, 
        'name': names
    }
    return data

project_df = pd.DataFrame(generateProjects())
project_df
# Out:
#                                       id  \
# 0   b50a26e1-e402-40f2-b4d3-bece517857a5
# 1   534819a3-6ed5-4b3b-982e-f952e606bf1d
# 2   7d045fb3-2ffb-4c9e-bf3a-12973c4e2731
# 3   3daa47dd-30ad-44e0-9889-20849f1f71bf
# 4   26af498a-2693-479e-8435-226d8eb9e180
# 5   6f412776-0411-4517-a282-504350fb2614
# 6   a708fc56-674e-42be-bb88-20e219326d28
# 7   619459f8-14f3-4304-8e5e-181999d7889c
# 8   abaf73cb-15a9-479c-ad7e-076d787eb3de
# 9   3706011e-9485-4054-adc2-0d570617b03c
# 10  df6c3695-1820-491d-9f84-68ec997e52f3
# 11  00c35d94-0cdb-482a-b8f4-773804d9e5d4
# 12  d9a6f98e-9c73-40dc-80f5-ecb8447db3c8
# 13  f575f45f-30b4-4e3b-b95b-5b0a769d4822
# 14  b1b18e1f-7be2-4495-aba1-8f88b22b639b
# 15  6a870829-af15-4639-9223-1d654cdc6eef
# 16  8bcd7470-a96e-4faa-aa1c-2ed24622c876
# 17  0e13be87-0fc9-4565-912a-eba4e4851050
# 18  67777866-f53e-47ba-8cb0-4a2734d5d6d6
# 19  07bb27a3-bc42-421f-a909-40965322cbfc
# 20  1e2f9167-9c2e-4372-bf3d-04c7db8ab636
# 21  4279b9c6-6d28-4737-8692-16fdcf8cd5f0
# 22  6ae2dc78-b9eb-474f-a09f-7e0d097a405a
# 23  737eb5ce-137d-48ff-ad02-86450835fff9
# 24  c158f8cb-45fc-42ae-855e-7975dddd8562
# 25  5efbd56f-8f18-4643-b766-d66b916eb884
# 26  6f353620-4cca-47a7-91a3-e43557cebf57
# 27  01eeb075-566a-4d4e-84da-edcb382bf6ae
# 28  77e1a8cf-3f3a-483f-b463-1df319fdda63
# 29  9eb29289-b972-42ee-967b-bae61bf20f74
# 30  aaf95563-404b-409f-a776-8e45f2d89c48
# 31  f775b687-44dd-4e9e-8892-e6f3831a4e73
# 32  2c378a6c-d5f2-4d7f-b35c-5b16ff532ede
# 33  f406f6b6-3b31-4653-a5a0-fd2b627a03d7
# 34  d1e648a6-a642-4ff7-be47-c9c3e0565307
# 35  cdb675d7-c435-4f7e-824e-f9348a47c2b6
# 36  45ad8fdd-c4b2-4ded-863b-44114f1096ab
# 37  e148ca49-d7b9-479f-b3c3-b2cd61b76ad4
# 38  ff75547c-9d72-400f-80d2-1bc14d2262be
# 39  31e2ec01-c25d-40d2-a5d3-7c837a11b186
# 40  ac779d43-df8a-40f1-8a11-16fd37e8985c
# 41  22c41c95-1c8c-4ded-9ecc-be896c152ec8
# 42  c96f9939-9fd6-4e6f-a0f8-f244ee9a2afb
# 43  0f356135-0d0b-49b6-a538-2f8173d67390
# 44  ef65f700-ade1-4eff-a960-433a4aa8a297
# 45  852d2c73-53a7-4e3d-8860-8ea5b6594796
# 46  5ce7e561-bc54-494a-ad2f-0f1f454aea55
# 47  de2f1ebd-cc51-4975-90bb-eee2fd049509
# 48  8b18b61c-2283-4dbe-b905-2b58e02d7dbe
# 49  99a09010-da51-452d-a3fc-f0e78bc23929
#
#                                       name
# 0                 Pierce and Sons Solution
# 1                    Weaver Group Solution
# 2                    Harrison LLC Solution
# 3               Harris-Randolph Initiative
# 4                     Knox-Pope Initiative
# 5                     Yoder Inc Initiative
# 6       Hale, Gray and Martinez Initiative
# 7                       Shaw-Lara Solution
# 8        Johnson, Pierce and Davis Project
# 9                        Lewis PLC Project
# 10              Shaffer-Donovan Initiative
# 11                     Love Inc Initiative
# 12    Silva, Wright and Schmidt Initiative
# 13                  Davis-Sullivan Project
# 14                   Nguyen-Cox Initiative
# 15                     Wright PLC Solution
# 16               Carson-Clayton Initiative
# 17                      Thomas Inc Project
# 18                    Lucas Inc Initiative
# 19    Lopez, Ramirez and Harris Initiative
# 20                Warren-Ingram Initiative
# 21  Adams, Stewart and Thompson Initiative
# 22       Rice, Jones and Harris Initiative
# 23                 Williams LLC Initiative
# 24                 Lam-Garrison Initiative
# 25                     Ford-Gibson Project
# 26                   Martinez Inc Solution
# 27                  Roberts Ltd Initiative
# 28                      Singh Ltd Solution
# 29                      Morgan Inc Project
# 30     Webster, Wiley and Phillips Project
# 31                  Bell-Henderson Project
# 32                  Sanchez Inc Initiative
# 33                      Boyer Inc Solution
# 34                  Vasquez PLC Initiative
# 35                  Nolan-Clark Initiative
# 36       Smith, Richard and Arroyo Project
# 37                  Clark Group Initiative
# 38                   Hale-Aguilar Solution
# 39                    Miller Group Project
# 40                 Bailey-Jimenez Solution
# 41  Johnson, Williams and Stanley Solution
# 42                 Walker-Evans Initiative
# 43                  White-Holland Solution
# 44             Rodriguez-Fletcher Solution
# 45    Monroe, Campbell and Mack Initiative
# 46                    White-Lozano Project
# 47          Lam, Fisher and Abbott Project
# 48      Hall, Copeland and Fuller Solution
# 49               Lyons-Harrison Initiative

# %%
def generateFeedbackQuestions():
    ids = []
    feedback_questions = ['How satisfied are you with the overall progress of the project?', 'Rate the communication between team members on a scale of 1 to 5', 'Did you find the project timeline realistic? Please rate from 1 to 5', 'How would you rate the quality of work delivered by the team?', 'Rate the effectiveness of the project management on a scale of 1 to 5', 'Were the project goals clearly defined? Please rate from 1 to 5', 'How satisfied are you with the level of collaboration within the team?', 'Rate the accuracy of the project budget estimation from 1 to 5', 'Did the project meet your expectations? Please rate from 1 to 5', 'How would you rate the problem-solving skills of the team?', 'Rate the level of stakeholder engagement on a scale of 1 to 5', 'Were the project risks effectively managed? Please rate from 1 to 5', 'How satisfied are you with the project deliverables?', 'Rate the level of innovation demonstrated in the project from 1 to 5', 'Did the project meet the specified deadlines? Please rate from 1 to 5', 'How would you rate the level of client satisfaction with the project outcomes?', 'Rate the effectiveness of the project feedback mechanisms on a scale of 1 to 5', 'Were the project resources allocated efficiently? Please rate from 1 to 5', 'How satisfied are you with the level of transparency in project communication?', 'Rate the level of adaptability shown by the team members on a scale of 1 to 5']

    for _ in range(len(feedback_questions)):

        while True:
            question_id = str(uuid.uuid4())
            if question_id not in ids:
                break

        ids.append(question_id)
    
    data = {
        'id': ids, 
        'question': feedback_questions
    }
    return data

feedbackQuestion_df = pd.DataFrame(generateFeedbackQuestions())
feedbackQuestion_df
# Out:
#                                       id  \
# 0   1a30e2b3-6907-414c-a2c3-18ce49c72a2a
# 1   74ad55c5-7b90-42cc-bf24-b2dcdef1e42b
# 2   a2ad7058-2b3b-4a3c-87d1-9937e8ad1c18
# 3   6b551f10-2629-4f2e-b73e-e7c4c809a0fa
# 4   6dd5b03a-abc8-4532-a8e9-2317f1d15ce0
# 5   c81f160c-404b-46b2-beed-440f63f86758
# 6   7b96aca8-51c4-47a3-bd48-4e9e524caeac
# 7   91546abd-f9e9-4465-a152-6349bd7b5cd5
# 8   1d8c4b67-1a17-4667-8625-001fb924d73c
# 9   f8027606-b1b5-4708-a7bf-3f1d7e5bbf7c
# 10  486a031a-d632-4c61-ad83-4ea2e7d04628
# 11  a350e27e-7e94-4517-b4b5-3fdca1b13f09
# 12  05ab630b-ae66-4a21-8f6c-21ed7a18d72d
# 13  6874a337-b104-4239-873a-500d8bafdb9b
# 14  938b1611-c3aa-4413-9067-4743b1ba3098
# 15  b914c01f-e214-4658-9e3d-39ea52ce2ea0
# 16  226d2491-4b06-4ebf-894d-20cb0f665eec
# 17  8af4a7db-3b63-4055-a3a9-cf7acd53c1d8
# 18  b036e82b-3e9e-4340-bf56-edf1bc63d46e
# 19  713e5604-1762-4838-99ef-a6242d70d9f0
#
#                                              question
# 0   How satisfied are you with the overall progres...
# 1   Rate the communication between team members on...
# 2   Did you find the project timeline realistic? P...
# 3   How would you rate the quality of work deliver...
# 4   Rate the effectiveness of the project manageme...
# 5   Were the project goals clearly defined? Please...
# 6   How satisfied are you with the level of collab...
# 7   Rate the accuracy of the project budget estima...
# 8   Did the project meet your expectations? Please...
# 9   How would you rate the problem-solving skills ...
# 10  Rate the level of stakeholder engagement on a ...
# 11  Were the project risks effectively managed? Pl...
# 12  How satisfied are you with the project deliver...
# 13  Rate the level of innovation demonstrated in t...
# 14  Did the project meet the specified deadlines? ...
# 15  How would you rate the level of client satisfa...
# 16  Rate the effectiveness of the project feedback...
# 17  Were the project resources allocated efficient...
# 18  How satisfied are you with the level of transp...
# 19  Rate the level of adaptability shown by the te...

# %%
def generateProjectsToUsers(): 
    project_names = random.choices(project_df['name'], k=num_projects_to_users)
    user_emails = random.choices(users_df['email'], k=num_projects_to_users)

    data = {
        'projectName': project_names,
        'userEmail': user_emails
    }
    return data

projectsToUsers_df = pd.DataFrame(generateProjectsToUsers())
projectsToUsers_df
# Out:
#                                projectName                   userEmail
# 0                   Clark Group Initiative    simmonsbilly@example.org
# 1                 Warren-Ingram Initiative      jennawhite@example.org
# 2       Hale, Gray and Martinez Initiative        isabel39@example.org
# 3                Carson-Clayton Initiative         logan81@example.org
# 4                  Lam-Garrison Initiative  antonioleonard@example.net
# ...                                    ...                         ...
# 4995               Bailey-Jimenez Solution       fthompson@example.com
# 4996                   Wright PLC Solution     rogersbrian@example.org
# 4997  Monroe, Campbell and Mack Initiative     brownyvette@example.org
# 4998    Hale, Gray and Martinez Initiative         jason35@example.com
# 4999                    Shaw-Lara Solution    halljonathan@example.net
#
# [5000 rows x 2 columns]

# %%
def generateProjectsToFeedbackQuestions(): 
    project_names = random.choices(project_df['name'], k=num_projects_to_feedback_question)
    question_names = random.choices(feedbackQuestion_df['question'], k=num_projects_to_feedback_question)

    data = {
        'projectName': project_names,
        'questionName': question_names
    }
    return data

projectsToFeedbackQuestions_df = pd.DataFrame(generateProjectsToFeedbackQuestions())
projectsToFeedbackQuestions_df
# Out:
#                               projectName  \
# 0     Webster, Wiley and Phillips Project
# 1                   Martinez Inc Solution
# 2       Johnson, Pierce and Davis Project
# 3                 Bailey-Jimenez Solution
# 4          Lam, Fisher and Abbott Project
# ...                                   ...
# 1995            Carson-Clayton Initiative
# 1996                 White-Lozano Project
# 1997            Lyons-Harrison Initiative
# 1998                   Thomas Inc Project
# 1999                 Lucas Inc Initiative
#
#                                            questionName
# 0     How would you rate the level of client satisfa...
# 1     Rate the accuracy of the project budget estima...
# 2     Rate the effectiveness of the project manageme...
# 3     Rate the level of stakeholder engagement on a ...
# 4     Were the project goals clearly defined? Please...
# ...                                                 ...
# 1995  Rate the level of adaptability shown by the te...
# 1996  Were the project goals clearly defined? Please...
# 1997  Rate the accuracy of the project budget estima...
# 1998  How satisfied are you with the level of collab...
# 1999  How satisfied are you with the level of collab...
#
# [2000 rows x 2 columns]

# %%
def generate_random_sunday():
    # Get today's date
    today = datetime.today()

    # Generate a random number of days to subtract to get a past date
    random_days = random.randint(0, 365 * 2)  # Adjust the range as needed

    # Subtract the random number of days from today's date
    random_date = today - timedelta(days=random_days)

    # Find the nearest Sunday before or on the random date
    while random_date.weekday() != 6:  # Sunday is represented by 6
        random_date -= timedelta(days=1)

    return {
            'formated': random_date.strftime('%d-%m-%Y'),
            'original': random_date
        }

def generateTimesheets() :

    comments_choices = ["Excited to get started!", "Looking forward to the challenge", "Ready to dive in", "Feeling motivated", "Can't wait to see the end result", "Feeling optimistic about this project", "Hopeful for a successful outcome", "Eager to collaborate with the team"]
    hours_choices = np.arange(0, 13)
    weekend_weights = [6, 6, 5, 4, 1, 1, 1, 1, 1, 1, 1, 1, 1]
    normal_weights = [1, 1, 1, 1, 6, 5, 4, 1, 1, 1, 1, 1, 1]
    activity_names_choices = ['BAU Activity', 'Sales Activity']

    user_emails = []
    date_starts = []
    date_ends = []
    projects_selected = []
    tasks_selected = []
    comments_added = []
    d0s = []
    d1s = []
    d2s = []
    d3s = []
    d4s = []
    d5s = []
    d6s = []
    activity_names = []

    # Generate and store random data for each row
    for _ in range(num_timesheets):
        random_projecstToUsers = projectsToUsers_df.sample()
        user_email = random_projecstToUsers['userEmail'].iloc[0]
        project_name = random_projecstToUsers['projectName'].iloc[0]

        random_sunday = generate_random_sunday()
        date_start = random_sunday['formated']
        date_end = (random_sunday['original'] + timedelta(days=6)).strftime('%d-%m-%Y')

        task_selected = None
        comment_added = random.choices(comments_choices)[0] if random.random() > 0.5 else None

        d0 = np.random.choice(hours_choices, p=np.array(weekend_weights)/sum(weekend_weights)) if random.random() > 0.3 else None
        d1 = np.random.choice(hours_choices, p=np.array(normal_weights)/sum(normal_weights)) if random.random() > 0.3 else None
        d2 = np.random.choice(hours_choices, p=np.array(normal_weights)/sum(normal_weights)) if random.random() > 0.3 else None
        d3 = np.random.choice(hours_choices, p=np.array(normal_weights)/sum(normal_weights)) if random.random() > 0.3 else None
        d4 = np.random.choice(hours_choices, p=np.array(normal_weights)/sum(normal_weights)) if random.random() > 0.3 else None
        d5 = np.random.choice(hours_choices, p=np.array(normal_weights)/sum(normal_weights)) if random.random() > 0.3 else None
        d6 = np.random.choice(hours_choices, p=np.array(weekend_weights)/sum(weekend_weights)) if random.random() > 0.3 else None
        
        activity_name = random.choice(activity_names_choices)

        user_emails.append(user_email)
        projects_selected.append(project_name)
        date_starts.append(date_start)
        date_ends.append(date_end)
        tasks_selected.append(task_selected)
        comments_added.append(comment_added)
        d0s.append(d0)
        d1s.append(d1)
        d2s.append(d2)
        d3s.append(d3)
        d4s.append(d4)
        d5s.append(d5)
        d6s.append(d6)
        activity_names.append(activity_name)

    data = {
        'userEmail': user_emails,
        'projectSelected': projects_selected,
        'dateStart': date_starts,
        'dateEnd': date_ends,
        'taskSelected': tasks_selected,
        'commentAdded': comments_added,
        'd0': d0s,
        'd1': d1s,
        'd2': d2s,
        'd3': d3s,
        'd4': d4s,
        'd5': d5s,
        'd6': d6s,
        'activityName': activity_names
    }

    return data

timesheets_df = pd.DataFrame(generateTimesheets())
timesheets_df
# Out:
#                         userEmail                       projectSelected  \
# 0            jerome92@example.net               Bailey-Jimenez Solution
# 1           tfletcher@example.org                Davis-Sullivan Project
# 2             diane50@example.net                Sanchez Inc Initiative
# 3         conniesmith@example.net  Monroe, Campbell and Mack Initiative
# 4        ronaldpatton@example.net                  Lucas Inc Initiative
# ...                           ...                                   ...
# 9995  georgegutierrez@example.net                  White-Lozano Project
# 9996       pereztracy@example.net     Rice, Jones and Harris Initiative
# 9997         tmccarty@example.com             Carson-Clayton Initiative
# 9998       mcervantes@example.com     Smith, Richard and Arroyo Project
# 9999        zmcdonald@example.com                   Ford-Gibson Project
#
#        dateStart     dateEnd taskSelected                        commentAdded  \
# 0     25-12-2022  31-12-2022         None                                None
# 1     17-04-2022  23-04-2022         None                                None
# 2     03-03-2024  09-03-2024         None    Hopeful for a successful outcome
# 3     29-05-2022  04-06-2022         None                                None
# 4     28-01-2024  03-02-2024         None                                None
# ...          ...         ...          ...                                 ...
# 9995  19-02-2023  25-02-2023         None    Can't wait to see the end result
# 9996  01-05-2022  07-05-2022         None  Eager to collaborate with the team
# 9997  07-05-2023  13-05-2023         None                                None
# 9998  10-12-2023  16-12-2023         None                                None
# 9999  03-09-2023  09-09-2023         None                                None
#
#         d0    d1   d2   d3   d4    d5    d6    activityName
# 0     12.0   3.0  NaN  5.0  9.0  10.0   2.0    BAU Activity
# 1      2.0   NaN  NaN  NaN  5.0   9.0   2.0  Sales Activity
# 2      5.0   4.0  NaN  3.0  4.0  10.0   3.0  Sales Activity
# 3      NaN   4.0  3.0  NaN  4.0   NaN   1.0  Sales Activity
# 4      NaN  11.0  5.0  4.0  NaN   5.0   3.0    BAU Activity
# ...    ...   ...  ...  ...  ...   ...   ...             ...
# 9995   0.0   5.0  NaN  6.0  5.0   6.0   5.0  Sales Activity
# 9996   NaN   8.0  7.0  5.0  4.0   NaN   3.0    BAU Activity
# 9997   5.0   6.0  8.0  NaN  2.0   NaN   6.0  Sales Activity
# 9998   1.0   5.0  1.0  NaN  NaN   5.0   2.0    BAU Activity
# 9999   7.0   4.0  NaN  NaN  4.0   6.0  12.0  Sales Activity
#
# [10000 rows x 14 columns]

# %%
def generateFeedbackAnswers():

    text_answer_choices = ['Excellent', 'Good', 'Average', 'Fair', 'Poor']

    project_names = []
    feedback_question_names = []
    checked_answers = []
    text_answers = []
    date_starts = []
    date_ends = []
    user_emails = []

    for _ in range(num_feedback_answers):

        random_projectsToFeedbackQuestions = projectsToFeedbackQuestions_df.sample()
        project_name = random_projectsToFeedbackQuestions['projectName'].iloc[0]
        feedback_question_name = random_projectsToFeedbackQuestions['questionName'].iloc[0]

        corresponding_random_timesheet = timesheets_df[timesheets_df['projectSelected'] == project_name].sample()
        date_start = corresponding_random_timesheet['dateStart'].iloc[0]
        date_end = corresponding_random_timesheet['dateEnd'].iloc[0]
        user_email = corresponding_random_timesheet['userEmail'].iloc[0]

        checked_answer = random.randint(1, 5) if random.random() > 0.2 else None
        text_answer = random.choice(text_answer_choices) if random.random() > 0.8 else None

        project_names.append(project_name)
        feedback_question_names.append(feedback_question_name)
        date_starts.append(date_start)
        date_ends.append(date_end)
        user_emails.append(user_email)
        checked_answers.append(checked_answer)
        text_answers.append(text_answer)

    data = {
        'projectName': project_names,
        'feedbackQuestionName': feedback_question_names,
        'dateStart': date_starts,
        'dateEnd': date_ends,
        'userEmail': user_emails,
        'checkedAnswer': checked_answers,
        'textAnswer': text_answers
    }

    return data

feedbackAnswers_df = pd.DataFrame(generateFeedbackAnswers())
feedbackAnswers_df
# Out:
#                              projectName  \
# 0                   White-Lozano Project
# 1                   Yoder Inc Initiative
# 2               Warren-Ingram Initiative
# 3             Harris-Randolph Initiative
# 4                    Ford-Gibson Project
# ...                                  ...
# 7995  Hall, Copeland and Fuller Solution
# 7996           Carson-Clayton Initiative
# 7997              White-Holland Solution
# 7998                Miller Group Project
# 7999             Williams LLC Initiative
#
#                                    feedbackQuestionName   dateStart  \
# 0     How would you rate the level of client satisfa...  21-08-2022
# 1     Rate the effectiveness of the project feedback...  08-01-2023
# 2     Were the project risks effectively managed? Pl...  04-02-2024
# 3     How satisfied are you with the project deliver...  25-02-2024
# 4     Rate the communication between team members on...  11-12-2022
# ...                                                 ...         ...
# 7995  Rate the level of adaptability shown by the te...  05-02-2023
# 7996  How satisfied are you with the level of collab...  24-04-2022
# 7997  Rate the accuracy of the project budget estima...  10-09-2023
# 7998  Did the project meet the specified deadlines? ...  05-03-2023
# 7999  Did the project meet the specified deadlines? ...  30-10-2022
#
#          dateEnd                  userEmail  checkedAnswer textAnswer
# 0     27-08-2022   rogersthomas@example.net            1.0       None
# 1     14-01-2023      stephen10@example.net            3.0       None
# 2     10-02-2024          qvega@example.org            NaN       None
# 3     02-03-2024         gmyers@example.com            3.0       None
# 4     17-12-2022      johnlewis@example.net            2.0       None
# ...          ...                        ...            ...        ...
# 7995  11-02-2023    smithashley@example.com            2.0       None
# 7996  30-04-2022         zowens@example.net            NaN       None
# 7997  16-09-2023       daniel69@example.net            1.0       None
# 7998  11-03-2023  crawfordlance@example.com            NaN       None
# 7999  05-11-2022        yhudson@example.org            NaN       None
#
# [8000 rows x 7 columns]

# %%
if not os.path.exists('csvs'):
    os.makedirs('csvs')

users_df.to_csv('csvs/users.csv', index=False)
project_df.to_csv('csvs/projects.csv', index=False)
feedbackQuestion_df.to_csv('csvs/feedbackQuestions.csv', index=False)
projectsToUsers_df.to_csv('csvs/projectsToUsers.csv', index=False)
projectsToFeedbackQuestions_df.to_csv('csvs/projectsToFeedbackQuestions.csv', index=False)
timesheets_df.to_csv('csvs/timesheets.csv', index=False)
feedbackAnswers_df.to_csv('csvs/feedbackAnswers.csv', index=False)
