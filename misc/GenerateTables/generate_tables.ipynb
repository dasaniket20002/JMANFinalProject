# %%
import pandas as pd
import numpy as np
import uuid
import random
from faker import Faker
import bcrypt
from datetime import datetime, timedelta
import os

# %%
fake = Faker()

num_users = 5000
num_projects = 50

num_projects_to_users = 5000
num_projects_to_feedback_question = 2000

num_timesheets = 10000
num_feedback_answers = 8000

# %%
def generateUsers() :
    roles = ['admin', 'user', 'manager', 'employee']
    weights = [10, 50, 20, 20]

    email_ids = []
    passwords = []
    roles_list = []
    names = []

    password = bcrypt.hashpw('org_pass_1234'.encode('utf-8'), bcrypt.gensalt()).decode('utf-8')

    # Generate and store random data for each row
    for _ in range(num_users):
        while True:
            email = fake.email()
            if email not in email_ids:
                break
        role = np.random.choice(roles, p=np.array(weights)/sum(weights))
        name = fake.name()

        email_ids.append(email)
        passwords.append(password)
        roles_list.append(role)
        names.append(name)

    # Create a DataFrame
    data = {
        'email': email_ids,
        'pass': passwords,
        'role': roles_list,
        'name': names
    }

    return data

users_df = pd.DataFrame(generateUsers())
users_df
# Out:
#                              email  \
# 0       kimberlyhaynes@example.com
# 1              grant38@example.com
# 2          ballpatrick@example.net
# 3        lopezjennifer@example.net
# 4      martineznatasha@example.net
# ...                            ...
# 4995          brenda77@example.org
# 4996             dchoi@example.com
# 4997  richardrodriguez@example.com
# 4998     shortjennifer@example.com
# 4999        lgallagher@example.com
#
#                                                    pass      role  \
# 0     $2b$12$hNxYtVbazBur0g4/iz2KQe6HkbNnvH5XVzEujgb...      user
# 1     $2b$12$hNxYtVbazBur0g4/iz2KQe6HkbNnvH5XVzEujgb...     admin
# 2     $2b$12$hNxYtVbazBur0g4/iz2KQe6HkbNnvH5XVzEujgb...      user
# 3     $2b$12$hNxYtVbazBur0g4/iz2KQe6HkbNnvH5XVzEujgb...      user
# 4     $2b$12$hNxYtVbazBur0g4/iz2KQe6HkbNnvH5XVzEujgb...      user
# ...                                                 ...       ...
# 4995  $2b$12$hNxYtVbazBur0g4/iz2KQe6HkbNnvH5XVzEujgb...   manager
# 4996  $2b$12$hNxYtVbazBur0g4/iz2KQe6HkbNnvH5XVzEujgb...  employee
# 4997  $2b$12$hNxYtVbazBur0g4/iz2KQe6HkbNnvH5XVzEujgb...  employee
# 4998  $2b$12$hNxYtVbazBur0g4/iz2KQe6HkbNnvH5XVzEujgb...      user
# 4999  $2b$12$hNxYtVbazBur0g4/iz2KQe6HkbNnvH5XVzEujgb...   manager
#
#                       name
# 0              Jorge Lewis
# 1            Curtis Ortega
# 2     Christopher Humphrey
# 3          Christina Banks
# 4            Marcus Hanson
# ...                    ...
# 4995         Leslie Knight
# 4996            Jeff Marsh
# 4997        Robert Richard
# 4998        Deborah Massey
# 4999       Latoya Phillips
#
# [5000 rows x 4 columns]

# %%
def generateProjects():
    project_domain_choices = ['Financial Services', 'Healthcare', 'Education Technology', 'E-commerce', 'Transportation and Logistics', 'Renewable Energy', 'Artificial Intelligence and Machine Learning', 'Cybersecurity', 'Media and Entertainment', 'Telecommunications']
    ids = []
    names = []
    domains = []

    for _ in range(num_projects):

        while True:
            project_id = str(uuid.uuid4())
            if project_id not in ids:
                break

        while True:
            project_name = fake.company() + " " + fake.word(ext_word_list=['Project', 'Solution', 'Initiative'])
            if project_name not in names:
                break
        
        project_domain = random.choice(project_domain_choices)

        ids.append(project_id)
        names.append(project_name)
        domains.append(project_domain)
    
    data = {
        'id': ids, 
        'name': names,
        'domain': domains
    }
    return data

project_df = pd.DataFrame(generateProjects())
project_df
# Out:
#                                       id  \
# 0   50053ffa-96aa-4494-94b9-d9330b81fe9d
# 1   d4e0fec4-0117-435d-abd8-52afd1d20ea2
# 2   22d2a96c-bb93-40af-8682-cdea6b45fc48
# 3   c3de9633-a182-4841-9ca5-3b251ca9fe35
# 4   05f36a38-8c60-4f6a-b5f2-51e666f33bc6
# 5   1dfa8aa1-af13-461f-b671-d238523e05b2
# 6   b65d69e0-06cd-483b-bd7f-39358f91dc26
# 7   f46aa804-2724-496f-9b52-82014c7ee1e0
# 8   f6ffb81a-a76f-42b6-93d7-5b70eb25b8f7
# 9   28deece0-a11d-4b90-8a28-dc3556cdf8d7
# 10  e0bb24af-4a1f-4889-a6ec-fb4f239a2563
# 11  5c88073f-c560-4ee1-8562-b2a7b35337c0
# 12  728684ec-894f-42a5-b4e6-7a336e3fda3b
# 13  ecd82428-41f8-43aa-bf31-585f0aa048ac
# 14  025be9ae-89c1-4b32-995e-aedb18fca76f
# 15  747eae87-f0bb-4637-babc-6a92f367f4df
# 16  2366ad84-78cc-4f11-965f-de7a58d0571f
# 17  460d2c09-23a1-467b-82a7-79eed87550f5
# 18  867ed8d7-6e71-4696-b1d6-26189a193d02
# 19  c39dce76-ed4f-48ad-b0b9-5521263ad9be
# 20  0d2f733f-e9e4-40e4-b4e4-a8505552a0bd
# 21  f45d2164-93a4-454d-ab94-3e4bbda3b25c
# 22  cf604edb-f6fe-4839-891c-2924e84e8c7f
# 23  967f9f5d-7963-4e29-9848-1248ff2650c1
# 24  dfee7f15-a70f-4914-8ed0-c2f723e12188
# 25  8ea3b8e4-169b-42f0-a332-462f311384aa
# 26  8530c4f3-1f02-444a-a4aa-9ab166c86418
# 27  1637b3d9-6718-4e14-8805-c1b30383f151
# 28  66bfb659-1062-425b-a3e8-44e3d6e26fab
# 29  35ac7a93-6c1c-49c0-962e-c940458104ef
# 30  ecaf3ed4-9e5f-48a0-b237-a58a667ba773
# 31  9d91358c-3967-4bf8-9cc1-9316b34fd462
# 32  8f042fb8-208e-4bf7-b51e-f319fbd70273
# 33  10b96a3c-3b4c-432b-87ab-873b9a0f84eb
# 34  71fd0e5c-aa55-4e2f-8912-f8eeaaca8158
# 35  a7b586e1-79a7-4fa2-bbe1-aaf75dce7f9c
# 36  de57cab8-a354-4725-8bfc-058f5b33d81a
# 37  a90a69e6-24b7-4151-85c5-1c8c5c148ef8
# 38  620431bc-5ce7-40bc-95a0-7011e93f3482
# 39  466d7e61-cab4-4d56-8265-e72796e3fd62
# 40  2fe7ae2e-42c8-4f3c-83ab-69077e6d50a5
# 41  4ddc4c7d-696e-4483-8191-48425cef993d
# 42  b8e010b3-2263-4540-b241-96ea25fb207d
# 43  3fdf4e28-b4af-4a73-bbed-dcb9bee37532
# 44  32a81f98-0a1a-459f-b574-5485fa0c22e0
# 45  597cf17f-e8c0-4b2d-8ab4-c86e6446d7c8
# 46  0ccc4164-f8bc-483e-8bbe-6275158d1dd1
# 47  e4d1f609-ca47-4fa4-8e1e-f694d42b0690
# 48  bed4eb6e-4c98-416a-92ac-0d9e1ede04c3
# 49  d36578e6-b107-4994-9acc-0d21e487037a
#
#                                       name  \
# 0               Gonzalez-Becker Initiative
# 1     Nguyen, Peters and Walker Initiative
# 2                   Abbott-Carter Solution
# 3                      Martin-Ball Project
# 4                     Brown Inc Initiative
# 5                Stevenson-Johnson Project
# 6                Serrano and Sons Solution
# 7       Brown, Vasquez and Bush Initiative
# 8                      Cabrera Inc Project
# 9                     Hurley Group Project
# 10     Donovan, Tyler and Cabrera Solution
# 11                  Lindsey Inc Initiative
# 12                      Taylor LLC Project
# 13   Sanchez, Jackson and Scott Initiative
# 14    Jackson, Nguyen and Crawford Project
# 15                       Love Ltd Solution
# 16   Austin, Barnes and Marquez Initiative
# 17                   Dalton Group Solution
# 18                Simpson-Caldwell Project
# 19                       Ford LLC Solution
# 20                Harris-Nicholson Project
# 21                  Henry-Sandoval Project
# 22      Chase, Molina and Mccoy Initiative
# 23                    Lin-Johnson Solution
# 24               Malone-Mcclure Initiative
# 25                  Scott and Sons Project
# 26        Brown, Sims and Davis Initiative
# 27                  Butler-Acosta Solution
# 28                    Lopez Inc Initiative
# 29                     Li-Schwartz Project
# 30                   Castillo PLC Solution
# 31          Lang, Allen and Hayes Solution
# 32                        Snow-Lee Project
# 33                   Greene Inc Initiative
# 34         Turner, Evans and Reed Solution
# 35        Mckinney, Ross and Reed Solution
# 36    Gonzalez, Anderson and Walsh Project
# 37                    Meyers-Nunez Project
# 38                    Ward-Berg Initiative
# 39    Jimenez, Mendez and Lewis Initiative
# 40                  Patrick Inc Initiative
# 41                    Austin-Clark Project
# 42  Strickland, Roberts and Dixon Solution
# 43  Stevens, Andrews and Medina Initiative
# 44       Adams, Mcgee and Baker Initiative
# 45              Hernandez-Wells Initiative
# 46             Schneider and Sons Solution
# 47                  Herrera Ltd Initiative
# 48                  Moreno-Jackson Project
# 49         Diaz, Lam and Maldonado Project
#
#                                           domain
# 0                             Telecommunications
# 1                                     Healthcare
# 2                                  Cybersecurity
# 3                             Financial Services
# 4                   Transportation and Logistics
# 5                                     E-commerce
# 6                                  Cybersecurity
# 7                             Telecommunications
# 8                             Telecommunications
# 9                                     E-commerce
# 10                                 Cybersecurity
# 11                          Education Technology
# 12                                    Healthcare
# 13                          Education Technology
# 14                                    E-commerce
# 15                                    Healthcare
# 16  Artificial Intelligence and Machine Learning
# 17                          Education Technology
# 18                       Media and Entertainment
# 19                                    E-commerce
# 20                          Education Technology
# 21                                    E-commerce
# 22                                    E-commerce
# 23  Artificial Intelligence and Machine Learning
# 24                              Renewable Energy
# 25                            Financial Services
# 26                  Transportation and Logistics
# 27                                    E-commerce
# 28  Artificial Intelligence and Machine Learning
# 29  Artificial Intelligence and Machine Learning
# 30                                    Healthcare
# 31                            Telecommunications
# 32                  Transportation and Logistics
# 33                                    Healthcare
# 34                  Transportation and Logistics
# 35  Artificial Intelligence and Machine Learning
# 36                              Renewable Energy
# 37                              Renewable Energy
# 38                                    E-commerce
# 39                       Media and Entertainment
# 40                                 Cybersecurity
# 41                            Financial Services
# 42                                    E-commerce
# 43  Artificial Intelligence and Machine Learning
# 44                                 Cybersecurity
# 45                       Media and Entertainment
# 46                                 Cybersecurity
# 47                              Renewable Energy
# 48  Artificial Intelligence and Machine Learning
# 49                                 Cybersecurity

# %%
def generateFeedbackQuestions():
    ids = []
    feedback_questions = ['How satisfied are you with the overall progress of the project?', 'Rate the communication between team members on a scale of 1 to 5', 'Did you find the project timeline realistic? Please rate from 1 to 5', 'How would you rate the quality of work delivered by the team?', 'Rate the effectiveness of the project management on a scale of 1 to 5', 'Were the project goals clearly defined? Please rate from 1 to 5', 'How satisfied are you with the level of collaboration within the team?', 'Rate the accuracy of the project budget estimation from 1 to 5', 'Did the project meet your expectations? Please rate from 1 to 5', 'How would you rate the problem-solving skills of the team?', 'Rate the level of stakeholder engagement on a scale of 1 to 5', 'Were the project risks effectively managed? Please rate from 1 to 5', 'How satisfied are you with the project deliverables?', 'Rate the level of innovation demonstrated in the project from 1 to 5', 'Did the project meet the specified deadlines? Please rate from 1 to 5', 'How would you rate the level of client satisfaction with the project outcomes?', 'Rate the effectiveness of the project feedback mechanisms on a scale of 1 to 5', 'Were the project resources allocated efficiently? Please rate from 1 to 5', 'How satisfied are you with the level of transparency in project communication?', 'Rate the level of adaptability shown by the team members on a scale of 1 to 5']

    for _ in range(len(feedback_questions)):

        while True:
            question_id = str(uuid.uuid4())
            if question_id not in ids:
                break

        ids.append(question_id)
    
    data = {
        'id': ids, 
        'question': feedback_questions
    }
    return data

feedbackQuestion_df = pd.DataFrame(generateFeedbackQuestions())
feedbackQuestion_df
# Out:
#                                       id  \
# 0   a7daa3fa-69db-42df-930c-19babbb440b8
# 1   1a93aa51-6d3f-49ed-8044-376418ca79e4
# 2   26d46b3b-5d98-4715-9f63-2053bc60f32c
# 3   987cd9f8-7c5d-452a-b1ea-7c6acec3cd16
# 4   cdcd19fb-995b-4096-9051-26db9c49b8fd
# 5   9a5e7c95-a3f8-47ae-aa88-4f03c74c74e0
# 6   8e28412a-0615-47aa-8ea1-5ca5f2ce8f18
# 7   ce7311c4-37a8-42e4-8c9b-769c6d7c7ab1
# 8   5fb5b911-697a-4db2-911f-98a122d4aa17
# 9   63805f7e-1d87-4bca-b399-c7b5f44be9ea
# 10  e3cbbeee-1128-44cc-9035-84fe9ec90622
# 11  f677327c-2bac-4f2b-a47f-bf7eaa26a2ab
# 12  c1659b89-de55-4809-852c-fda17706ce41
# 13  c4f3a491-154c-40d3-9b1d-e371e8e3e2bd
# 14  4a298b02-3690-4f9a-82dd-8cda5a0c755f
# 15  fd1cf0fa-a517-4162-b79b-9a1364270dbd
# 16  ddeae3af-96cf-4479-84ef-cab92571fe97
# 17  0e78568a-6191-4a81-b0b9-a52469ba56c1
# 18  99e1e3ad-a8d1-460d-ba60-96a568e69dd1
# 19  31f00a14-14be-418a-91e9-d29c69708edd
#
#                                              question
# 0   How satisfied are you with the overall progres...
# 1   Rate the communication between team members on...
# 2   Did you find the project timeline realistic? P...
# 3   How would you rate the quality of work deliver...
# 4   Rate the effectiveness of the project manageme...
# 5   Were the project goals clearly defined? Please...
# 6   How satisfied are you with the level of collab...
# 7   Rate the accuracy of the project budget estima...
# 8   Did the project meet your expectations? Please...
# 9   How would you rate the problem-solving skills ...
# 10  Rate the level of stakeholder engagement on a ...
# 11  Were the project risks effectively managed? Pl...
# 12  How satisfied are you with the project deliver...
# 13  Rate the level of innovation demonstrated in t...
# 14  Did the project meet the specified deadlines? ...
# 15  How would you rate the level of client satisfa...
# 16  Rate the effectiveness of the project feedback...
# 17  Were the project resources allocated efficient...
# 18  How satisfied are you with the level of transp...
# 19  Rate the level of adaptability shown by the te...

# %%
def generateProjectsToUsers(): 
    project_names = random.choices(project_df['name'], k=num_projects_to_users)
    user_emails = random.choices(users_df['email'], k=num_projects_to_users)

    data = {
        'projectName': project_names,
        'userEmail': user_emails
    }
    return data

projectsToUsers_df = pd.DataFrame(generateProjectsToUsers())
projectsToUsers_df
# Out:
#                                  projectName                  userEmail
# 0                     Moreno-Jackson Project    paynegeorge@example.org
# 1                        Martin-Ball Project        julia57@example.net
# 2                        Martin-Ball Project     josewilson@example.org
# 3                   Simpson-Caldwell Project    alansherman@example.com
# 4           Brown, Sims and Davis Initiative     ambersmith@example.net
# ...                                      ...                        ...
# 4995                   Castillo PLC Solution      kristin30@example.net
# 4996                    Lin-Johnson Solution  flowerssylvia@example.net
# 4997  Stevens, Andrews and Medina Initiative           fray@example.net
# 4998              Hernandez-Wells Initiative    paulakeller@example.net
# 4999               Serrano and Sons Solution      kristin25@example.net
#
# [5000 rows x 2 columns]

# %%
def generateProjectsToFeedbackQuestions(): 
    project_names = random.choices(project_df['name'], k=num_projects_to_feedback_question)
    question_names = random.choices(feedbackQuestion_df['question'], k=num_projects_to_feedback_question)

    data = {
        'projectName': project_names,
        'questionName': question_names
    }
    return data

projectsToFeedbackQuestions_df = pd.DataFrame(generateProjectsToFeedbackQuestions())
projectsToFeedbackQuestions_df
# Out:
#                                projectName  \
# 0                        Ford LLC Solution
# 1                   Scott and Sons Project
# 2                      Cabrera Inc Project
# 3     Gonzalez, Anderson and Walsh Project
# 4                     Brown Inc Initiative
# ...                                    ...
# 1995                Lindsey Inc Initiative
# 1996    Chase, Molina and Mccoy Initiative
# 1997                      Snow-Lee Project
# 1998                  Brown Inc Initiative
# 1999            Hernandez-Wells Initiative
#
#                                            questionName
# 0     Rate the level of innovation demonstrated in t...
# 1     How satisfied are you with the level of transp...
# 2     Rate the level of stakeholder engagement on a ...
# 3     Were the project risks effectively managed? Pl...
# 4     Were the project risks effectively managed? Pl...
# ...                                                 ...
# 1995  Did you find the project timeline realistic? P...
# 1996  How would you rate the quality of work deliver...
# 1997  Did the project meet your expectations? Please...
# 1998  Rate the level of stakeholder engagement on a ...
# 1999  Rate the communication between team members on...
#
# [2000 rows x 2 columns]

# %%
def generate_random_sunday():
    # Get today's date
    today = datetime.today()

    # Generate a random number of days to subtract to get a past date
    random_days = random.randint(0, 365 * 2)  # Adjust the range as needed

    # Subtract the random number of days from today's date
    random_date = today - timedelta(days=random_days)

    # Find the nearest Sunday before or on the random date
    while random_date.weekday() != 6:  # Sunday is represented by 6
        random_date -= timedelta(days=1)

    return {
            'formated': random_date.strftime('%d-%m-%Y'),
            'original': random_date
        }

def generateTimesheets() :

    comments_choices = ["Excited to get started!", "Looking forward to the challenge", "Ready to dive in", "Feeling motivated", "Can't wait to see the end result", "Feeling optimistic about this project", "Hopeful for a successful outcome", "Eager to collaborate with the team"]
    hours_choices = np.arange(0, 13)
    weekend_weights = [6, 6, 5, 4, 1, 1, 1, 1, 1, 1, 1, 1, 1]
    normal_weights = [1, 1, 1, 1, 6, 5, 4, 1, 1, 1, 1, 1, 1]
    activity_names_choices = ['BAU Activity', 'Sales Activity']

    user_emails = []
    date_starts = []
    date_ends = []
    projects_selected = []
    tasks_selected = []
    comments_added = []
    d0s = []
    d1s = []
    d2s = []
    d3s = []
    d4s = []
    d5s = []
    d6s = []
    activity_names = []

    # Generate and store random data for each row
    for _ in range(num_timesheets):
        random_projecstToUsers = projectsToUsers_df.sample()
        user_email = random_projecstToUsers['userEmail'].iloc[0]
        project_name = random_projecstToUsers['projectName'].iloc[0]

        random_sunday = generate_random_sunday()
        date_start = random_sunday['formated']
        date_end = (random_sunday['original'] + timedelta(days=6)).strftime('%d-%m-%Y')

        task_selected = None
        comment_added = random.choices(comments_choices)[0] if random.random() > 0.5 else None

        d0 = np.random.choice(hours_choices, p=np.array(weekend_weights)/sum(weekend_weights)) if random.random() > 0.3 else None
        d1 = np.random.choice(hours_choices, p=np.array(normal_weights)/sum(normal_weights)) if random.random() > 0.3 else None
        d2 = np.random.choice(hours_choices, p=np.array(normal_weights)/sum(normal_weights)) if random.random() > 0.3 else None
        d3 = np.random.choice(hours_choices, p=np.array(normal_weights)/sum(normal_weights)) if random.random() > 0.3 else None
        d4 = np.random.choice(hours_choices, p=np.array(normal_weights)/sum(normal_weights)) if random.random() > 0.3 else None
        d5 = np.random.choice(hours_choices, p=np.array(normal_weights)/sum(normal_weights)) if random.random() > 0.3 else None
        d6 = np.random.choice(hours_choices, p=np.array(weekend_weights)/sum(weekend_weights)) if random.random() > 0.3 else None
        
        activity_name = random.choice(activity_names_choices)

        user_emails.append(user_email)
        projects_selected.append(project_name)
        date_starts.append(date_start)
        date_ends.append(date_end)
        tasks_selected.append(task_selected)
        comments_added.append(comment_added)
        d0s.append(d0)
        d1s.append(d1)
        d2s.append(d2)
        d3s.append(d3)
        d4s.append(d4)
        d5s.append(d5)
        d6s.append(d6)
        activity_names.append(activity_name)

    data = {
        'userEmail': user_emails,
        'projectSelected': projects_selected,
        'dateStart': date_starts,
        'dateEnd': date_ends,
        'taskSelected': tasks_selected,
        'commentAdded': comments_added,
        'd0': d0s,
        'd1': d1s,
        'd2': d2s,
        'd3': d3s,
        'd4': d4s,
        'd5': d5s,
        'd6': d6s,
        'activityName': activity_names
    }

    return data

timesheets_df = pd.DataFrame(generateTimesheets())
timesheets_df
# Out:
#                         userEmail                         projectSelected  \
# 0              ygreen@example.org             Schneider and Sons Solution
# 1     jacksonjennifer@example.org          Lang, Allen and Hayes Solution
# 2          maysnicole@example.org                     Martin-Ball Project
# 3       matthewwilson@example.com  Stevens, Andrews and Medina Initiative
# 4              chad42@example.net   Austin, Barnes and Marquez Initiative
# ...                           ...                                     ...
# 9995          qortega@example.org                  Moreno-Jackson Project
# 9996    julieshepherd@example.org                  Henry-Sandoval Project
# 9997        bryanmoss@example.net                       Ford LLC Solution
# 9998   franciscobaker@example.com                   Castillo PLC Solution
# 9999      stephanie43@example.com   Sanchez, Jackson and Scott Initiative
#
#        dateStart     dateEnd taskSelected                      commentAdded  \
# 0     24-03-2024  30-03-2024         None                              None
# 1     02-04-2023  08-04-2023         None  Can't wait to see the end result
# 2     18-06-2023  24-06-2023         None                              None
# 3     17-12-2023  23-12-2023         None  Can't wait to see the end result
# 4     21-05-2023  27-05-2023         None  Looking forward to the challenge
# ...          ...         ...          ...                               ...
# 9995  02-04-2023  08-04-2023         None  Looking forward to the challenge
# 9996  05-02-2023  11-02-2023         None  Can't wait to see the end result
# 9997  19-02-2023  25-02-2023         None                              None
# 9998  29-05-2022  04-06-2022         None                              None
# 9999  22-10-2023  28-10-2023         None           Excited to get started!
#
#         d0    d1   d2   d3   d4   d5    d6    activityName
# 0      2.0   NaN  5.0  5.0  5.0  6.0   NaN  Sales Activity
# 1      NaN   6.0  5.0  5.0  NaN  NaN   2.0  Sales Activity
# 2      0.0   4.0  NaN  NaN  NaN  NaN   3.0    BAU Activity
# 3      NaN   6.0  4.0  NaN  NaN  NaN   NaN  Sales Activity
# 4      2.0   6.0  4.0  4.0  NaN  NaN   2.0  Sales Activity
# ...    ...   ...  ...  ...  ...  ...   ...             ...
# 9995   2.0  11.0  6.0  NaN  9.0  5.0   1.0    BAU Activity
# 9996   0.0   4.0  6.0  4.0  7.0  NaN   NaN    BAU Activity
# 9997   NaN   5.0  5.0  NaN  1.0  4.0  11.0  Sales Activity
# 9998  12.0  11.0  4.0  4.0  NaN  3.0  12.0  Sales Activity
# 9999   9.0   8.0  6.0  0.0  4.0  4.0   2.0    BAU Activity
#
# [10000 rows x 14 columns]

# %%
def generateFeedbackAnswers():

    text_answer_choices = ['Excellent', 'Good', 'Average', 'Fair', 'Poor']

    project_names = []
    feedback_question_names = []
    checked_answers = []
    text_answers = []
    date_starts = []
    date_ends = []
    user_emails = []

    for _ in range(num_feedback_answers):

        random_projectsToFeedbackQuestions = projectsToFeedbackQuestions_df.sample()
        project_name = random_projectsToFeedbackQuestions['projectName'].iloc[0]
        feedback_question_name = random_projectsToFeedbackQuestions['questionName'].iloc[0]

        corresponding_random_timesheet = timesheets_df[timesheets_df['projectSelected'] == project_name].sample()
        date_start = corresponding_random_timesheet['dateStart'].iloc[0]
        date_end = corresponding_random_timesheet['dateEnd'].iloc[0]
        user_email = corresponding_random_timesheet['userEmail'].iloc[0]

        checked_answer = random.randint(1, 5) if random.random() > 0.2 else None
        text_answer = random.choice(text_answer_choices) if random.random() > 0.8 else None

        project_names.append(project_name)
        feedback_question_names.append(feedback_question_name)
        date_starts.append(date_start)
        date_ends.append(date_end)
        user_emails.append(user_email)
        checked_answers.append(checked_answer)
        text_answers.append(text_answer)

    data = {
        'projectName': project_names,
        'feedbackQuestionName': feedback_question_names,
        'dateStart': date_starts,
        'dateEnd': date_ends,
        'userEmail': user_emails,
        'checkedAnswer': checked_answers,
        'textAnswer': text_answers
    }

    return data

feedbackAnswers_df = pd.DataFrame(generateFeedbackAnswers())
feedbackAnswers_df
# Out:
#                              projectName  \
# 0                 Abbott-Carter Solution
# 1              Stevenson-Johnson Project
# 2                 Abbott-Carter Solution
# 3                 Herrera Ltd Initiative
# 4       Brown, Sims and Davis Initiative
# ...                                  ...
# 7995         Schneider and Sons Solution
# 7996    Brown, Sims and Davis Initiative
# 7997  Brown, Vasquez and Bush Initiative
# 7998      Lang, Allen and Hayes Solution
# 7999    Brown, Sims and Davis Initiative
#
#                                    feedbackQuestionName   dateStart  \
# 0     How satisfied are you with the level of transp...  21-08-2022
# 1     Rate the effectiveness of the project manageme...  24-07-2022
# 2     How satisfied are you with the level of transp...  02-04-2023
# 3     How satisfied are you with the project deliver...  07-01-2024
# 4     Rate the effectiveness of the project manageme...  10-12-2023
# ...                                                 ...         ...
# 7995  Rate the effectiveness of the project manageme...  11-09-2022
# 7996  How would you rate the problem-solving skills ...  21-08-2022
# 7997  Rate the effectiveness of the project feedback...  05-03-2023
# 7998  How satisfied are you with the level of transp...  31-03-2024
# 7999  Did the project meet your expectations? Please...  31-12-2023
#
#          dateEnd                   userEmail  checkedAnswer textAnswer
# 0     27-08-2022          bgreen@example.org            3.0       None
# 1     30-07-2022    jenniferlevy@example.net            3.0       None
# 2     08-04-2023    johnsonerica@example.org            5.0       None
# 3     13-01-2024   nguyentiffany@example.net            5.0       Good
# 4     16-12-2023      ambersmith@example.net            5.0       None
# ...          ...                         ...            ...        ...
# 7995  17-09-2022       pmorrison@example.net            1.0  Excellent
# 7996  27-08-2022     johnkennedy@example.com            1.0       None
# 7997  11-03-2023           csims@example.org            2.0       None
# 7998  06-04-2024  mcmillansherri@example.net            2.0       None
# 7999  06-01-2024         xgibson@example.org            1.0       None
#
# [8000 rows x 7 columns]

# %%
if not os.path.exists('csvs'):
    os.makedirs('csvs')

users_df.to_csv('csvs/users.csv', index=False)
project_df.to_csv('csvs/projects.csv', index=False)
feedbackQuestion_df.to_csv('csvs/feedbackQuestions.csv', index=False)
projectsToUsers_df.to_csv('csvs/projectsToUsers.csv', index=False)
projectsToFeedbackQuestions_df.to_csv('csvs/projectsToFeedbackQuestions.csv', index=False)
timesheets_df.to_csv('csvs/timesheets.csv', index=False)
feedbackAnswers_df.to_csv('csvs/feedbackAnswers.csv', index=False)
