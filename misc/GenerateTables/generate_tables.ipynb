# %%
import pandas as pd
import numpy as np
import uuid
import random
from faker import Faker
import bcrypt
from datetime import datetime, timedelta
import os
import time
import math

# %%
fake = Faker()

num_users = 5000
num_projects = 50

num_feedback_answers = 8000

# %%
def generateUsers() :
    roles = ['admin', 'user', 'manager', 'employee']
    weights = [10, 50, 20, 20]

    email_ids = []
    passwords = []
    roles_list = []
    names = []

    password = bcrypt.hashpw('org_pass_1234'.encode('utf-8'), bcrypt.gensalt()).decode('utf-8')

    # Generate and store random data for each row
    for _ in range(num_users):
        while True:
            email = fake.email()
            if email not in email_ids:
                break
        role = np.random.choice(roles, p=np.array(weights)/sum(weights))
        name = fake.name()

        email_ids.append(email)
        passwords.append(password)
        roles_list.append(role)
        names.append(name)

    # Create a DataFrame
    data = {
        'email': email_ids,
        'pass': passwords,
        'role': roles_list,
        'name': names
    }

    return data

users_df = pd.DataFrame(generateUsers())
users_df
# Out:
#                           email  \
# 0           wbriggs@example.net
# 1           ywilson@example.com
# 2     wilsonanthony@example.org
# 3         bstephens@example.net
# 4         eschaefer@example.net
# ...                         ...
# 4995        mritter@example.net
# 4996        emily52@example.org
# 4997        julia63@example.org
# 4998  wallerheather@example.com
# 4999  rodneyfischer@example.org
#
#                                                    pass      role  \
# 0     $2b$12$CfQEFX9iEiWxEgaqGJO5wO0Yw5RUHPK7zes274R...      user
# 1     $2b$12$CfQEFX9iEiWxEgaqGJO5wO0Yw5RUHPK7zes274R...  employee
# 2     $2b$12$CfQEFX9iEiWxEgaqGJO5wO0Yw5RUHPK7zes274R...     admin
# 3     $2b$12$CfQEFX9iEiWxEgaqGJO5wO0Yw5RUHPK7zes274R...  employee
# 4     $2b$12$CfQEFX9iEiWxEgaqGJO5wO0Yw5RUHPK7zes274R...  employee
# ...                                                 ...       ...
# 4995  $2b$12$CfQEFX9iEiWxEgaqGJO5wO0Yw5RUHPK7zes274R...      user
# 4996  $2b$12$CfQEFX9iEiWxEgaqGJO5wO0Yw5RUHPK7zes274R...      user
# 4997  $2b$12$CfQEFX9iEiWxEgaqGJO5wO0Yw5RUHPK7zes274R...  employee
# 4998  $2b$12$CfQEFX9iEiWxEgaqGJO5wO0Yw5RUHPK7zes274R...   manager
# 4999  $2b$12$CfQEFX9iEiWxEgaqGJO5wO0Yw5RUHPK7zes274R...     admin
#
#                    name
# 0            Steven Fox
# 1        William Harvey
# 2         Wayne Walters
# 3        Marilyn Watson
# 4         Ashley Stokes
# ...                 ...
# 4995  Jessica Hernandez
# 4996       Michele Peck
# 4997     Alicia English
# 4998    Dennis Martinez
# 4999      Lisa Anderson
#
# [5000 rows x 4 columns]

# %%
def generateProjects():
    project_domain_choices = ['Financial Services', 'Healthcare', 'Education Technology', 'E-commerce', 'Transportation and Logistics', 'Renewable Energy', 'Artificial Intelligence and Machine Learning', 'Cybersecurity', 'Media and Entertainment', 'Telecommunications']
    ids = []
    names = []
    domains = []

    for _ in range(num_projects):

        while True:
            project_id = str(uuid.uuid4())
            if project_id not in ids:
                break

        while True:
            project_name = fake.company() + " " + fake.word(ext_word_list=['Project', 'Solution', 'Initiative'])
            if project_name not in names:
                break
        
        project_domain = random.choice(project_domain_choices)

        ids.append(project_id)
        names.append(project_name)
        domains.append(project_domain)
    
    data = {
        'id': ids, 
        'name': names,
        'domain': domains
    }
    return data

project_df = pd.DataFrame(generateProjects())
project_df
# Out:
#                                       id  \
# 0   1246e477-bca6-4c1e-913b-2a12cb3325ae
# 1   0b776229-ce8b-4cff-ba8f-f6be0d908328
# 2   bdfed411-79b4-4208-86e7-ef7362580a04
# 3   54f468f9-02e7-48c9-9d87-e8afd5e508ba
# 4   914fa739-f1da-40f4-83ed-fd690363046b
# 5   d5962b60-bc79-421c-b338-39f9770c8a88
# 6   137b761a-ec7c-425f-8c96-0e2e0615e494
# 7   b82b4770-3724-4b89-8a9b-e057588d933e
# 8   655659e4-cd5a-4c19-84d9-530ade35266b
# 9   1f3fa3c4-0a1e-4a93-a0af-c8a8f5e48439
# 10  3586436a-f2dc-4b2f-a4e1-0f3352589bfd
# 11  d79b0229-1f36-4ddd-b32f-2795005bae0f
# 12  e10b2a7f-9540-4481-ac32-eef382bfc801
# 13  080b0256-3264-498c-af11-31a8e6b93ef8
# 14  8a377930-9508-4e07-a6a8-575d92715545
# 15  2e6c56da-1124-434e-a616-5ad8e48afe4a
# 16  6642569b-ee18-492f-a500-5528132c80ef
# 17  ed0c266b-26d3-4352-a680-58147b7dc643
# 18  009cb6aa-fed3-421e-9ff2-d9aad2cdc96b
# 19  e664e417-0708-4c3c-9c04-4b7e4597946b
# 20  16d05447-12be-4a44-ad6b-02c623454133
# 21  53d8c142-908e-4bca-b5a9-de3f5c0dc21e
# 22  ef37b962-b2f7-4b2b-8527-6a2a73034d1e
# 23  4e1ce51a-5d70-4524-9124-fd20e3ac9acc
# 24  01963dd5-16b8-4c2b-926c-183653b4c864
# 25  66db013e-f41a-45a1-a383-6123fc537d8a
# 26  e6310f13-fe6f-466c-99e3-e8a8f1e56d00
# 27  6a76d00c-cf0e-43eb-904f-4f04de42f09f
# 28  57a48353-a42a-4b34-aaa8-acd7ddc69d9b
# 29  984312a7-f8c2-4cbb-8f53-13370e952a05
# 30  9cb24f00-219b-4c62-a42d-d1e50b9f49af
# 31  c8668a31-756a-4a1f-8f77-23b5863da0f7
# 32  cfb5f65a-9d91-4e32-8328-e35f345c2813
# 33  48b962f8-a34d-426c-a112-13d0fbbcb56c
# 34  e674be3c-6004-450c-b618-ee17eebab0bb
# 35  e97171bc-59a6-4e81-bc05-bbb450e3d45a
# 36  24c604f6-c322-4e76-80af-175ca37ebe3c
# 37  02159768-1246-4b9e-b6e1-03ef91c616c1
# 38  0f1bd5d4-0297-49e4-9370-f10cee697ce9
# 39  c9406330-0156-4f1a-bf90-ea97452bef9b
# 40  41e35e95-0c9d-42dc-a172-23bff6fa4b4c
# 41  a66f19c4-09df-453e-bcf2-3b6be0ae7657
# 42  0c2567a7-2305-40f1-88bd-add97483f5b5
# 43  3911e4d9-29aa-4f5d-96f8-b7f8defa1633
# 44  3fd2c07c-eadf-4ba6-a013-a08c4df23b94
# 45  f06b9840-eecd-45b8-b653-d2c77c25824b
# 46  455bb117-2d65-4d2d-bfb7-a2beb6f4a1fc
# 47  460b06b3-8c56-4c1f-9587-6602bc336fbb
# 48  476ed748-7704-41b9-8cc7-22d5b4642ee3
# 49  0680bf9d-b896-4150-9975-a4c9b0c6f339
#
#                                       name  \
# 0                         Ward Ltd Project
# 1                    Saunders LLC Solution
# 2                        Green Ltd Project
# 3                Johnson-Duncan Initiative
# 4          Jones, Meyer and Smith Solution
# 5                    Parker-Osborn Project
# 6   Thompson, Adkins and Harris Initiative
# 7     Taylor, Elliott and Trevino Solution
# 8                       Moreno Ltd Project
# 9       Wilson, Jackson and Green Solution
# 10                       Smith PLC Project
# 11                Schneider-Tyler Solution
# 12                Allison and Sons Project
# 13                Randall-Reyes Initiative
# 14               Barnett-Harris Initiative
# 15        Ayala, Sexton and Casey Solution
# 16                 Watson-Mcdowell Project
# 17             Wheeler and Sons Initiative
# 18                   Middleton Ltd Project
# 19         Barron, Brown and Hicks Project
# 20                  Ross and Sons Solution
# 21                     Chaney Inc Solution
# 22       Roberts, Brown and Lee Initiative
# 23                  Colon-Oconnor Solution
# 24                     Solis-Smith Project
# 25                 Stanton-Pollard Project
# 26                Stewart Group Initiative
# 27                     Turner Inc Solution
# 28                    Olson-Craig Solution
# 29                     Andrews Inc Project
# 30               Mccarthy Group Initiative
# 31                       Frey LLC Solution
# 32      Castillo, Frey and Stewart Project
# 33               Mckenzie and Sons Project
# 34                 Campbell Inc Initiative
# 35                      Dennis LLC Project
# 36    French, Perez and Hernandez Solution
# 37                    Smith LLC Initiative
# 38     Cook, Campbell and Campbell Project
# 39                 Briggs-Jennings Project
# 40     Lopez, Bradley and Sharp Initiative
# 41        Hernandez, Smith and Lee Project
# 42      Francis, Quinn and Cook Initiative
# 43                Carpenter-Holmes Project
# 44                   Clarke Inc Initiative
# 45  Gonzales, Martin and Carter Initiative
# 46                  Kim-Gutierrez Solution
# 47                   Vargas Group Solution
# 48       Hill, Hernandez and Jones Project
# 49                    Davis LLC Initiative
#
#                                           domain
# 0   Artificial Intelligence and Machine Learning
# 1                                     Healthcare
# 2                           Education Technology
# 3   Artificial Intelligence and Machine Learning
# 4                             Telecommunications
# 5                                  Cybersecurity
# 6                                     Healthcare
# 7                        Media and Entertainment
# 8                             Financial Services
# 9                           Education Technology
# 10                            Financial Services
# 11                          Education Technology
# 12                                    Healthcare
# 13                                    Healthcare
# 14                       Media and Entertainment
# 15                            Financial Services
# 16                              Renewable Energy
# 17                            Telecommunications
# 18                                    E-commerce
# 19                          Education Technology
# 20                              Renewable Energy
# 21                       Media and Entertainment
# 22                                    E-commerce
# 23  Artificial Intelligence and Machine Learning
# 24  Artificial Intelligence and Machine Learning
# 25  Artificial Intelligence and Machine Learning
# 26                       Media and Entertainment
# 27                       Media and Entertainment
# 28                                 Cybersecurity
# 29                              Renewable Energy
# 30                  Transportation and Logistics
# 31                            Financial Services
# 32                            Telecommunications
# 33                                 Cybersecurity
# 34                       Media and Entertainment
# 35                                    Healthcare
# 36                            Telecommunications
# 37                                 Cybersecurity
# 38                            Financial Services
# 39                                    Healthcare
# 40                                    Healthcare
# 41                          Education Technology
# 42  Artificial Intelligence and Machine Learning
# 43                                 Cybersecurity
# 44                       Media and Entertainment
# 45                       Media and Entertainment
# 46                                    Healthcare
# 47                       Media and Entertainment
# 48                                 Cybersecurity
# 49                          Education Technology

# %%
def generateFeedbackQuestions():
    ids = []
    feedback_questions = ['How satisfied are you with the overall progress of the project?', 'Rate the communication between team members on a scale of 1 to 5', 'Did you find the project timeline realistic? Please rate from 1 to 5', 'How would you rate the quality of work delivered by the team?', 'Rate the effectiveness of the project management on a scale of 1 to 5', 'Were the project goals clearly defined? Please rate from 1 to 5', 'How satisfied are you with the level of collaboration within the team?', 'Rate the accuracy of the project budget estimation from 1 to 5', 'Did the project meet your expectations? Please rate from 1 to 5', 'How would you rate the problem-solving skills of the team?', 'Rate the level of stakeholder engagement on a scale of 1 to 5', 'Were the project risks effectively managed? Please rate from 1 to 5', 'How satisfied are you with the project deliverables?', 'Rate the level of innovation demonstrated in the project from 1 to 5', 'Did the project meet the specified deadlines? Please rate from 1 to 5', 'How would you rate the level of client satisfaction with the project outcomes?', 'Rate the effectiveness of the project feedback mechanisms on a scale of 1 to 5', 'Were the project resources allocated efficiently? Please rate from 1 to 5', 'How satisfied are you with the level of transparency in project communication?', 'Rate the level of adaptability shown by the team members on a scale of 1 to 5']

    for _ in range(len(feedback_questions)):

        while True:
            question_id = str(uuid.uuid4())
            if question_id not in ids:
                break

        ids.append(question_id)
    
    data = {
        'id': ids, 
        'question': feedback_questions
    }
    return data

feedbackQuestion_df = pd.DataFrame(generateFeedbackQuestions())
feedbackQuestion_df
# Out:
#                                       id  \
# 0   b8cb65a3-272a-41ca-a1ba-2691c561e237
# 1   62ae49a5-859a-4659-8333-114149fcc2e1
# 2   ba7a3c95-17d2-4a00-ae47-266a58b7e6d2
# 3   d1d33464-4bf2-4b2c-bf9d-7c73e64a2ddd
# 4   e0033b5b-134f-435d-a24c-5f258a6b6830
# 5   cf02cc06-32bb-4b96-87a3-62fdda3c2154
# 6   405b9801-a845-4267-877b-68c998043775
# 7   48abba80-f7f3-44f4-aa57-0e96b980fdbb
# 8   5d7afee3-b00b-4966-b1c7-6108d4cac23b
# 9   db2df44d-9801-4186-96a8-18f27e43623a
# 10  d1bd985f-45d4-4764-a014-d7a4bc1feb1b
# 11  4f91d619-8c07-4d79-8125-0a78a0de6393
# 12  c439243b-2a95-4130-8b60-018a592df49f
# 13  f9234fdd-a491-4e2b-97a8-f19aeaba329f
# 14  0e910acc-0d83-4b0a-bc65-c81e968ad985
# 15  b887f54d-026f-41b2-b367-7a0036407f62
# 16  66e384c0-fbca-47ba-91fc-032389062b48
# 17  76642daa-9e5a-4dfa-b9ff-5309e36c39b8
# 18  936f5716-f2dd-43b2-ad94-a69d396c9981
# 19  c17911e1-9b23-401d-99c5-0c1309ac6067
#
#                                              question
# 0   How satisfied are you with the overall progres...
# 1   Rate the communication between team members on...
# 2   Did you find the project timeline realistic? P...
# 3   How would you rate the quality of work deliver...
# 4   Rate the effectiveness of the project manageme...
# 5   Were the project goals clearly defined? Please...
# 6   How satisfied are you with the level of collab...
# 7   Rate the accuracy of the project budget estima...
# 8   Did the project meet your expectations? Please...
# 9   How would you rate the problem-solving skills ...
# 10  Rate the level of stakeholder engagement on a ...
# 11  Were the project risks effectively managed? Pl...
# 12  How satisfied are you with the project deliver...
# 13  Rate the level of innovation demonstrated in t...
# 14  Did the project meet the specified deadlines? ...
# 15  How would you rate the level of client satisfa...
# 16  Rate the effectiveness of the project feedback...
# 17  Were the project resources allocated efficient...
# 18  How satisfied are you with the level of transp...
# 19  Rate the level of adaptability shown by the te...

# %%
def generateProjectsToUsers(): 
    project_names = []
    user_emails = []
    for user_email in users_df['email']:
        projects = random.sample(list(project_df['name']), k=random.randint(1, project_df['name'].shape[0]))
        for project in projects:
            user_emails.append(user_email)
            project_names.append(project)

    data = {
        'projectName': project_names,
        'userEmail': user_emails
    }
    return data

projectsToUsers_df = pd.DataFrame(generateProjectsToUsers())
projectsToUsers_df
# Out:
#                                    projectName                  userEmail
# 0           Francis, Quinn and Cook Initiative        wbriggs@example.net
# 1                       Ross and Sons Solution        wbriggs@example.net
# 2                    Barnett-Harris Initiative        wbriggs@example.net
# 3       Gonzales, Martin and Carter Initiative        wbriggs@example.net
# 4           Castillo, Frey and Stewart Project        wbriggs@example.net
# ...                                        ...                        ...
# 127273                  Kim-Gutierrez Solution  rodneyfischer@example.org
# 127274      Wilson, Jackson and Green Solution  rodneyfischer@example.org
# 127275               Johnson-Duncan Initiative  rodneyfischer@example.org
# 127276       Hill, Hernandez and Jones Project  rodneyfischer@example.org
# 127277                   Vargas Group Solution  rodneyfischer@example.org
#
# [127278 rows x 2 columns]

# %%
def generateProjectsToFeedbackQuestions(): 
    project_names = []
    question_names = []
    for project in project_df['name']:
        questions = random.sample(list(feedbackQuestion_df['question']), k=random.randint(0, feedbackQuestion_df['question'].shape[0]))
        for question in questions:
            project_names.append(project)
            question_names.append(question)

    data = {
        'projectName': project_names,
        'questionName': question_names
    }
    return data

projectsToFeedbackQuestions_df = pd.DataFrame(generateProjectsToFeedbackQuestions())
projectsToFeedbackQuestions_df
# Out:
#                            projectName  \
# 0                     Ward Ltd Project
# 1                     Ward Ltd Project
# 2                     Ward Ltd Project
# 3                     Ward Ltd Project
# 4                     Ward Ltd Project
# ..                                 ...
# 516  Hill, Hernandez and Jones Project
# 517               Davis LLC Initiative
# 518               Davis LLC Initiative
# 519               Davis LLC Initiative
# 520               Davis LLC Initiative
#
#                                           questionName
# 0    Rate the level of adaptability shown by the te...
# 1    Rate the effectiveness of the project manageme...
# 2    Rate the level of stakeholder engagement on a ...
# 3    How would you rate the quality of work deliver...
# 4    Were the project risks effectively managed? Pl...
# ..                                                 ...
# 516  Rate the communication between team members on...
# 517  How satisfied are you with the level of collab...
# 518  Rate the effectiveness of the project manageme...
# 519  Rate the communication between team members on...
# 520  How would you rate the problem-solving skills ...
#
# [521 rows x 2 columns]

# %%
def generate_random_sunday():
    today = datetime.today()
    random_days = random.randint(0, 365 * 2) 
    random_date = today - timedelta(days=random_days)
    while random_date.weekday() != 6:
        random_date -= timedelta(days=1)

    return {
            'formated': random_date.strftime('%d-%m-%Y'),
            'original': random_date
        }

def generateTimesheets():
    comments_choices = ["Excited to get started!", "Looking forward to the challenge", "Ready to dive in", "Feeling motivated", "Can't wait to see the end result", "Feeling optimistic about this project", "Hopeful for a successful outcome", "Eager to collaborate with the team"]
    hours_choices = list(range(0, 12))
    weekend_weights = [3, 3, 2, 2, 1, 1, 1, 1, 1, 1, 1, 1]
    normal_weights = [1, 1, 1, 1, 1, 1, 1, 5, 10, 9, 3, 1]
    activity_names_choices = ['BAU Activity', 'Sales Activity']

    user_emails = []
    date_starts = []
    date_ends = []
    projects_selected = []
    tasks_selected = []
    comments_added = []
    d0s = []
    d1s = []
    d2s = []
    d3s = []
    d4s = []
    d5s = []
    d6s = []
    activity_names = []

    num_timesheets = 0

    for current_num_user in range(num_users):
        start_time = time.time()

        user_email = users_df['email'].iloc[current_num_user] if random.random() > 0.1 else None
        if user_email is None:
            continue

        project_list_under_user = projectsToUsers_df.groupby('userEmail')['projectName'].agg(list).get(user_email, [])
        # print('project_list_under_user: ', end='')
        # print(project_list_under_user)

        num_timesheets_for_current_user = random.randint(0, len(project_list_under_user))
        # print('num timesheets to generate for ' + str(user_email) + ': ' + str(num_timesheets_for_current_user))

        memoized_date_starts_for_project = []

        for _ in range(num_timesheets_for_current_user):

            random_sunday = generate_random_sunday()
            # print('finding date...')
            while random_sunday['formated'] in memoized_date_starts_for_project: # [date_starts[i] for i, project_item in enumerate([projects_selected[i] for i, email_item in enumerate(user_emails) if email_item == user_email]) if project_item == project_name]:
                random_sunday = generate_random_sunday()
            # print('found date: ' + str(random_sunday['formated']))

            date_start = random_sunday['formated']
            date_end = (random_sunday['original'] + timedelta(days=6)).strftime('%d-%m-%Y')

            memoized_date_starts_for_project.append(date_start)

            num_timesheets_for_random_day = random.randint(0, 4) # user can do atleast 4 projects in a day 
            if num_timesheets_for_random_day > len(project_list_under_user):
                num_timesheets_for_random_day = random.randint(0, len(project_list_under_user))

            project_names = random.sample(project_list_under_user, k=num_timesheets_for_random_day)

            # print('num timesheets to generate for ' + str(user_email) + ' | ' + str(project_name) + ': ' + str(num_timesheets_for_random_day))

            d0_num_hours_to_work = np.random.choice(hours_choices, p=np.array(weekend_weights)/sum(weekend_weights))
            d1_num_hours_to_work = np.random.choice(hours_choices, p=np.array(normal_weights)/sum(normal_weights))
            d2_num_hours_to_work = np.random.choice(hours_choices, p=np.array(normal_weights)/sum(normal_weights))
            d3_num_hours_to_work = np.random.choice(hours_choices, p=np.array(normal_weights)/sum(normal_weights))
            d4_num_hours_to_work = np.random.choice(hours_choices, p=np.array(normal_weights)/sum(normal_weights))
            d5_num_hours_to_work = np.random.choice(hours_choices, p=np.array(normal_weights)/sum(normal_weights))
            d6_num_hours_to_work = np.random.choice(hours_choices, p=np.array(weekend_weights)/sum(weekend_weights))

            for project_name in project_names:

                task_selected = None
                comment_added = random.choice(comments_choices) if random.random() > 0.5 else None

                d0 = (1 if math.ceil(d0_num_hours_to_work / num_timesheets_for_random_day) <= 1 else random.randint(1, math.ceil(d0_num_hours_to_work / num_timesheets_for_random_day))) if random.random() > 0.3 else None
                d1 = (1 if math.ceil(d1_num_hours_to_work / num_timesheets_for_random_day) <= 1 else random.randint(1, math.ceil(d1_num_hours_to_work / num_timesheets_for_random_day))) if random.random() > 0.3 else None
                d2 = (1 if math.ceil(d2_num_hours_to_work / num_timesheets_for_random_day) <= 1 else random.randint(1, math.ceil(d2_num_hours_to_work / num_timesheets_for_random_day))) if random.random() > 0.3 else None
                d3 = (1 if math.ceil(d3_num_hours_to_work / num_timesheets_for_random_day) <= 1 else random.randint(1, math.ceil(d3_num_hours_to_work / num_timesheets_for_random_day))) if random.random() > 0.3 else None
                d4 = (1 if math.ceil(d4_num_hours_to_work / num_timesheets_for_random_day) <= 1 else random.randint(1, math.ceil(d4_num_hours_to_work / num_timesheets_for_random_day))) if random.random() > 0.3 else None
                d5 = (1 if math.ceil(d5_num_hours_to_work / num_timesheets_for_random_day) <= 1 else random.randint(1, math.ceil(d5_num_hours_to_work / num_timesheets_for_random_day))) if random.random() > 0.3 else None
                d6 = (1 if math.ceil(d6_num_hours_to_work / num_timesheets_for_random_day) <= 1 else random.randint(1, math.ceil(d6_num_hours_to_work / num_timesheets_for_random_day))) if random.random() > 0.3 else None

                for activity_name in random.sample(activity_names_choices, k=random.randint(1, len(activity_names_choices))):
                    # print('activity for ' + str(user_email) + ' | ' + str(project_name) + ' | ' + str(date_start) + ': ' + str(activity_name))

                    user_emails.append(user_email)
                    projects_selected.append(project_name)
                    date_starts.append(date_start)
                    date_ends.append(date_end)
                    tasks_selected.append(task_selected)
                    comments_added.append(comment_added)
                    d0s.append(d0)
                    d1s.append(d1)
                    d2s.append(d2)
                    d3s.append(d3)
                    d4s.append(d4)
                    d5s.append(d5)
                    d6s.append(d6)
                    activity_names.append(activity_name)

                    num_timesheets += 1
        print(f'Added timesheets for: {user_email:30s}  | current_num_user: {current_num_user:4d} | total_users: {num_users:4d} | timesheet_count: {num_timesheets:8d} | ETA: {((num_users - current_num_user) * (time.time() - start_time)) / 60:4.0f} min | elapsed_time: {(time.time() - start_time) * 1000:4.0f} ms')

    data = {
        'userEmail': user_emails,
        'projectSelected': projects_selected,
        'dateStart': date_starts,
        'dateEnd': date_ends,
        'taskSelected': tasks_selected,
        'commentAdded': comments_added,
        'd0': d0s,
        'd1': d1s,
        'd2': d2s,
        'd3': d3s,
        'd4': d4s,
        'd5': d5s,
        'd6': d6s,
        'activityName': activity_names
    }

    return data

timesheets_df = pd.DataFrame(generateTimesheets())
timesheets_df
# Out:
# Added timesheets for: wbriggs@example.net             | current_num_user:    0 | total_users: 5000 | timesheet_count:       31 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: ywilson@example.com             | current_num_user:    1 | total_users: 5000 | timesheet_count:       31 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: bstephens@example.net           | current_num_user:    3 | total_users: 5000 | timesheet_count:       73 | ETA:    6 min | elapsed_time:   72 ms
# Added timesheets for: eschaefer@example.net           | current_num_user:    4 | total_users: 5000 | timesheet_count:      116 | ETA:    6 min | elapsed_time:   78 ms
# Added timesheets for: mariah97@example.net            | current_num_user:    5 | total_users: 5000 | timesheet_count:      191 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: toddbonilla@example.com         | current_num_user:    6 | total_users: 5000 | timesheet_count:      203 | ETA:   15 min | elapsed_time:  177 ms
# Added timesheets for: tina95@example.org              | current_num_user:    8 | total_users: 5000 | timesheet_count:      265 | ETA:    7 min | elapsed_time:   86 ms
# Added timesheets for: sparkswhitney@example.com       | current_num_user:    9 | total_users: 5000 | timesheet_count:      330 | ETA:    8 min | elapsed_time:   92 ms
# Added timesheets for: jesse21@example.com             | current_num_user:   10 | total_users: 5000 | timesheet_count:      353 | ETA:    7 min | elapsed_time:   81 ms
# Added timesheets for: jackwinters@example.com         | current_num_user:   11 | total_users: 5000 | timesheet_count:      375 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: panderson@example.org           | current_num_user:   12 | total_users: 5000 | timesheet_count:      378 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: ryanwood@example.net            | current_num_user:   13 | total_users: 5000 | timesheet_count:      462 | ETA:    7 min | elapsed_time:   81 ms
# Added timesheets for: davieselizabeth@example.com     | current_num_user:   14 | total_users: 5000 | timesheet_count:      608 | ETA:    7 min | elapsed_time:   83 ms
# Added timesheets for: bradleygabrielle@example.net    | current_num_user:   15 | total_users: 5000 | timesheet_count:      614 | ETA:    7 min | elapsed_time:   79 ms
# Added timesheets for: lmartin@example.org             | current_num_user:   16 | total_users: 5000 | timesheet_count:      628 | ETA:    6 min | elapsed_time:   72 ms
# Added timesheets for: cheryl68@example.net            | current_num_user:   17 | total_users: 5000 | timesheet_count:      734 | ETA:    7 min | elapsed_time:   81 ms
# Added timesheets for: michael09@example.org           | current_num_user:   18 | total_users: 5000 | timesheet_count:      751 | ETA:    6 min | elapsed_time:   69 ms
# Added timesheets for: banksalicia@example.net         | current_num_user:   19 | total_users: 5000 | timesheet_count:      751 | ETA:    6 min | elapsed_time:   67 ms
# Added timesheets for: joelrojas@example.net           | current_num_user:   20 | total_users: 5000 | timesheet_count:      766 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: thomas72@example.com            | current_num_user:   21 | total_users: 5000 | timesheet_count:      851 | ETA:    6 min | elapsed_time:   69 ms
# Added timesheets for: timothy20@example.net           | current_num_user:   22 | total_users: 5000 | timesheet_count:      858 | ETA:   13 min | elapsed_time:  158 ms
# Added timesheets for: dorothy46@example.org           | current_num_user:   23 | total_users: 5000 | timesheet_count:      949 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: joshua66@example.net            | current_num_user:   24 | total_users: 5000 | timesheet_count:      962 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: blogan@example.com              | current_num_user:   25 | total_users: 5000 | timesheet_count:      989 | ETA:    6 min | elapsed_time:   68 ms
# Added timesheets for: wjohnston@example.org           | current_num_user:   26 | total_users: 5000 | timesheet_count:     1037 | ETA:    6 min | elapsed_time:   67 ms
# Added timesheets for: dbryant@example.com             | current_num_user:   28 | total_users: 5000 | timesheet_count:     1096 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: fkane@example.net               | current_num_user:   30 | total_users: 5000 | timesheet_count:     1138 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: beverlyhudson@example.com       | current_num_user:   31 | total_users: 5000 | timesheet_count:     1139 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: rtaylor@example.org             | current_num_user:   32 | total_users: 5000 | timesheet_count:     1215 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: cobbdawn@example.net            | current_num_user:   33 | total_users: 5000 | timesheet_count:     1215 | ETA:    6 min | elapsed_time:   68 ms
# Added timesheets for: bhenderson@example.net          | current_num_user:   34 | total_users: 5000 | timesheet_count:     1310 | ETA:    6 min | elapsed_time:   67 ms
# Added timesheets for: hardinjessica@example.com       | current_num_user:   35 | total_users: 5000 | timesheet_count:     1310 | ETA:    6 min | elapsed_time:   67 ms
# Added timesheets for: kennethallen@example.com        | current_num_user:   36 | total_users: 5000 | timesheet_count:     1373 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: thomasscott@example.com         | current_num_user:   37 | total_users: 5000 | timesheet_count:     1433 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: monica92@example.com            | current_num_user:   38 | total_users: 5000 | timesheet_count:     1511 | ETA:    6 min | elapsed_time:   69 ms
# Added timesheets for: susanruiz@example.net           | current_num_user:   39 | total_users: 5000 | timesheet_count:     1522 | ETA:    6 min | elapsed_time:   72 ms
# Added timesheets for: jhuerta@example.org             | current_num_user:   40 | total_users: 5000 | timesheet_count:     1544 | ETA:    6 min | elapsed_time:   68 ms
# Added timesheets for: hreyes@example.net              | current_num_user:   43 | total_users: 5000 | timesheet_count:     1639 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: yolanda75@example.org           | current_num_user:   44 | total_users: 5000 | timesheet_count:     1640 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: michael43@example.org           | current_num_user:   45 | total_users: 5000 | timesheet_count:     1670 | ETA:    6 min | elapsed_time:   68 ms
# Added timesheets for: carlos30@example.net            | current_num_user:   46 | total_users: 5000 | timesheet_count:     1693 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: billybrown@example.org          | current_num_user:   47 | total_users: 5000 | timesheet_count:     1764 | ETA:   13 min | elapsed_time:  158 ms
# Added timesheets for: rwright@example.com             | current_num_user:   48 | total_users: 5000 | timesheet_count:     1784 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: emilyruiz@example.com           | current_num_user:   49 | total_users: 5000 | timesheet_count:     1828 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: clinton38@example.org           | current_num_user:   50 | total_users: 5000 | timesheet_count:     1836 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: simpsonbecky@example.net        | current_num_user:   52 | total_users: 5000 | timesheet_count:     1854 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: benitezstacy@example.org        | current_num_user:   53 | total_users: 5000 | timesheet_count:     1868 | ETA:    6 min | elapsed_time:   67 ms
# Added timesheets for: gillamy@example.net             | current_num_user:   54 | total_users: 5000 | timesheet_count:     1874 | ETA:    6 min | elapsed_time:   72 ms
# Added timesheets for: ryoung@example.net              | current_num_user:   55 | total_users: 5000 | timesheet_count:     1880 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: heatherhill@example.org         | current_num_user:   56 | total_users: 5000 | timesheet_count:     1916 | ETA:    6 min | elapsed_time:   68 ms
# Added timesheets for: laurenali@example.com           | current_num_user:   57 | total_users: 5000 | timesheet_count:     1963 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: showell@example.org             | current_num_user:   58 | total_users: 5000 | timesheet_count:     1977 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: chasekyle@example.net           | current_num_user:   59 | total_users: 5000 | timesheet_count:     1984 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: anthony14@example.com           | current_num_user:   60 | total_users: 5000 | timesheet_count:     2053 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: mark89@example.org              | current_num_user:   61 | total_users: 5000 | timesheet_count:     2055 | ETA:    6 min | elapsed_time:   68 ms
# Added timesheets for: dannymalone@example.com         | current_num_user:   62 | total_users: 5000 | timesheet_count:     2078 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: samanthaberry@example.net       | current_num_user:   63 | total_users: 5000 | timesheet_count:     2100 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: wsmith@example.com              | current_num_user:   64 | total_users: 5000 | timesheet_count:     2108 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: craigjohnson@example.org        | current_num_user:   65 | total_users: 5000 | timesheet_count:     2195 | ETA:   13 min | elapsed_time:  158 ms
# Added timesheets for: krodriguez@example.org          | current_num_user:   66 | total_users: 5000 | timesheet_count:     2267 | ETA:    7 min | elapsed_time:   91 ms
# Added timesheets for: ethan20@example.com             | current_num_user:   67 | total_users: 5000 | timesheet_count:     2330 | ETA:    7 min | elapsed_time:   84 ms
# Added timesheets for: fraziermisty@example.org        | current_num_user:   68 | total_users: 5000 | timesheet_count:     2456 | ETA:    7 min | elapsed_time:   83 ms
# Added timesheets for: shirleymoss@example.com         | current_num_user:   69 | total_users: 5000 | timesheet_count:     2456 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: pthomas@example.org             | current_num_user:   70 | total_users: 5000 | timesheet_count:     2456 | ETA:    6 min | elapsed_time:   69 ms
# Added timesheets for: aliciasimpson@example.org       | current_num_user:   71 | total_users: 5000 | timesheet_count:     2456 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: andersondonald@example.org      | current_num_user:   74 | total_users: 5000 | timesheet_count:     2521 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: parkkyle@example.com            | current_num_user:   75 | total_users: 5000 | timesheet_count:     2620 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: michael15@example.net           | current_num_user:   76 | total_users: 5000 | timesheet_count:     2703 | ETA:    6 min | elapsed_time:   68 ms
# Added timesheets for: brentmartin@example.com         | current_num_user:   77 | total_users: 5000 | timesheet_count:     2703 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: walkerzoe@example.net           | current_num_user:   78 | total_users: 5000 | timesheet_count:     2713 | ETA:    6 min | elapsed_time:   68 ms
# Added timesheets for: waynele@example.com             | current_num_user:   79 | total_users: 5000 | timesheet_count:     2715 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: ericporter@example.net          | current_num_user:   80 | total_users: 5000 | timesheet_count:     2743 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: holtsamuel@example.net          | current_num_user:   81 | total_users: 5000 | timesheet_count:     2756 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: ayalasteven@example.com         | current_num_user:   82 | total_users: 5000 | timesheet_count:     2759 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: lparker@example.com             | current_num_user:   85 | total_users: 5000 | timesheet_count:     2766 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: william72@example.com           | current_num_user:   86 | total_users: 5000 | timesheet_count:     2829 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: gregory23@example.com           | current_num_user:   87 | total_users: 5000 | timesheet_count:     2837 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: turnerkelly@example.org         | current_num_user:   88 | total_users: 5000 | timesheet_count:     2850 | ETA:   12 min | elapsed_time:  150 ms
# Added timesheets for: paul97@example.net              | current_num_user:   89 | total_users: 5000 | timesheet_count:     2869 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: sara65@example.com              | current_num_user:   90 | total_users: 5000 | timesheet_count:     2885 | ETA:    6 min | elapsed_time:   68 ms
# Added timesheets for: rachel03@example.com            | current_num_user:   91 | total_users: 5000 | timesheet_count:     2914 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: mjohnson@example.net            | current_num_user:   92 | total_users: 5000 | timesheet_count:     2940 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: dennisjerry@example.com         | current_num_user:   93 | total_users: 5000 | timesheet_count:     3019 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: morenobrittany@example.net      | current_num_user:   94 | total_users: 5000 | timesheet_count:     3049 | ETA:    6 min | elapsed_time:   68 ms
# Added timesheets for: michael12@example.com           | current_num_user:   95 | total_users: 5000 | timesheet_count:     3104 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: graycarolyn@example.net         | current_num_user:   96 | total_users: 5000 | timesheet_count:     3104 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: tlopez@example.org              | current_num_user:   97 | total_users: 5000 | timesheet_count:     3115 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: christopherbowman@example.com   | current_num_user:   98 | total_users: 5000 | timesheet_count:     3229 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: carsonabigail@example.net       | current_num_user:   99 | total_users: 5000 | timesheet_count:     3304 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: ingramlindsay@example.net       | current_num_user:  100 | total_users: 5000 | timesheet_count:     3309 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: christensenkaren@example.com    | current_num_user:  101 | total_users: 5000 | timesheet_count:     3314 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: brittanygiles@example.com       | current_num_user:  102 | total_users: 5000 | timesheet_count:     3322 | ETA:    6 min | elapsed_time:   68 ms
# Added timesheets for: xjames@example.net              | current_num_user:  103 | total_users: 5000 | timesheet_count:     3322 | ETA:   12 min | elapsed_time:  150 ms
# Added timesheets for: williamscott@example.net        | current_num_user:  104 | total_users: 5000 | timesheet_count:     3373 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: btodd@example.net               | current_num_user:  105 | total_users: 5000 | timesheet_count:     3386 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: scottdawson@example.org         | current_num_user:  106 | total_users: 5000 | timesheet_count:     3386 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: jenniferhicks@example.org       | current_num_user:  107 | total_users: 5000 | timesheet_count:     3408 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: shawnschwartz@example.com       | current_num_user:  108 | total_users: 5000 | timesheet_count:     3483 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: tmoore@example.com              | current_num_user:  109 | total_users: 5000 | timesheet_count:     3503 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: ccarrillo@example.com           | current_num_user:  110 | total_users: 5000 | timesheet_count:     3564 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: keith58@example.com             | current_num_user:  111 | total_users: 5000 | timesheet_count:     3569 | ETA:    6 min | elapsed_time:   70 ms
# Added timesheets for: daniel94@example.com            | current_num_user:  112 | total_users: 5000 | timesheet_count:     3569 | ETA:    5 min | elapsed_time:   64 ms
# Added timesheets for: nataliebowers@example.com       | current_num_user:  113 | total_users: 5000 | timesheet_count:     3638 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: hmorrison@example.com           | current_num_user:  114 | total_users: 5000 | timesheet_count:     3696 | ETA:    6 min | elapsed_time:   68 ms
# Added timesheets for: bradleymelissa@example.org      | current_num_user:  115 | total_users: 5000 | timesheet_count:     3761 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: nicholas89@example.org          | current_num_user:  116 | total_users: 5000 | timesheet_count:     3795 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: michael55@example.org           | current_num_user:  117 | total_users: 5000 | timesheet_count:     3834 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: brianrodriguez@example.net      | current_num_user:  118 | total_users: 5000 | timesheet_count:     3855 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: johndonovan@example.net         | current_num_user:  119 | total_users: 5000 | timesheet_count:     3915 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: andrewmendez@example.net        | current_num_user:  120 | total_users: 5000 | timesheet_count:     3915 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: victoria35@example.com          | current_num_user:  121 | total_users: 5000 | timesheet_count:     3915 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: gateskatherine@example.net      | current_num_user:  122 | total_users: 5000 | timesheet_count:     3916 | ETA:    6 min | elapsed_time:   69 ms
# Added timesheets for: qgreen@example.org              | current_num_user:  123 | total_users: 5000 | timesheet_count:     3916 | ETA:    6 min | elapsed_time:   70 ms
# Added timesheets for: chelseacarr@example.com         | current_num_user:  124 | total_users: 5000 | timesheet_count:     3994 | ETA:   12 min | elapsed_time:  152 ms
# Added timesheets for: cclark@example.org              | current_num_user:  126 | total_users: 5000 | timesheet_count:     4055 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: joneskaylee@example.com         | current_num_user:  127 | total_users: 5000 | timesheet_count:     4098 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: cookmonica@example.net          | current_num_user:  128 | total_users: 5000 | timesheet_count:     4198 | ETA:    6 min | elapsed_time:   76 ms
# Added timesheets for: ocampbell@example.org           | current_num_user:  130 | total_users: 5000 | timesheet_count:     4232 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: waremikayla@example.com         | current_num_user:  131 | total_users: 5000 | timesheet_count:     4296 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: kcruz@example.com               | current_num_user:  132 | total_users: 5000 | timesheet_count:     4304 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: eferguson@example.org           | current_num_user:  133 | total_users: 5000 | timesheet_count:     4323 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: dannychristensen@example.net    | current_num_user:  134 | total_users: 5000 | timesheet_count:     4326 | ETA:    6 min | elapsed_time:   68 ms
# Added timesheets for: cperez@example.net              | current_num_user:  135 | total_users: 5000 | timesheet_count:     4464 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: kelleyaaron@example.net         | current_num_user:  136 | total_users: 5000 | timesheet_count:     4469 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: markcampbell@example.com        | current_num_user:  138 | total_users: 5000 | timesheet_count:     4551 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: zmay@example.com                | current_num_user:  139 | total_users: 5000 | timesheet_count:     4583 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: wyatt66@example.com             | current_num_user:  140 | total_users: 5000 | timesheet_count:     4611 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: hannahjensen@example.com        | current_num_user:  141 | total_users: 5000 | timesheet_count:     4634 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: susan23@example.com             | current_num_user:  142 | total_users: 5000 | timesheet_count:     4674 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: davisdorothy@example.net        | current_num_user:  143 | total_users: 5000 | timesheet_count:     4682 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: boonejulie@example.org          | current_num_user:  144 | total_users: 5000 | timesheet_count:     4734 | ETA:   13 min | elapsed_time:  165 ms
# Added timesheets for: matthewjohnson@example.net      | current_num_user:  145 | total_users: 5000 | timesheet_count:     4745 | ETA:    5 min | elapsed_time:   68 ms
# Added timesheets for: emily38@example.com             | current_num_user:  146 | total_users: 5000 | timesheet_count:     4782 | ETA:    6 min | elapsed_time:   69 ms
# Added timesheets for: michael17@example.net           | current_num_user:  147 | total_users: 5000 | timesheet_count:     4805 | ETA:    6 min | elapsed_time:   71 ms
# Added timesheets for: nathanmccall@example.org        | current_num_user:  148 | total_users: 5000 | timesheet_count:     4836 | ETA:    6 min | elapsed_time:   69 ms
# Added timesheets for: jessica51@example.org           | current_num_user:  149 | total_users: 5000 | timesheet_count:     4891 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: wongmatthew@example.net         | current_num_user:  150 | total_users: 5000 | timesheet_count:     4902 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: jenningsdawn@example.net        | current_num_user:  152 | total_users: 5000 | timesheet_count:     4970 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: lsimmons@example.com            | current_num_user:  153 | total_users: 5000 | timesheet_count:     4974 | ETA:    6 min | elapsed_time:   68 ms
# Added timesheets for: kellybowen@example.net          | current_num_user:  154 | total_users: 5000 | timesheet_count:     5005 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: xaustin@example.net             | current_num_user:  155 | total_users: 5000 | timesheet_count:     5007 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: rodriguezlisa@example.org       | current_num_user:  156 | total_users: 5000 | timesheet_count:     5023 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: ovargas@example.org             | current_num_user:  157 | total_users: 5000 | timesheet_count:     5096 | ETA:    6 min | elapsed_time:   68 ms
# Added timesheets for: hjones@example.org              | current_num_user:  158 | total_users: 5000 | timesheet_count:     5105 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: davispatrick@example.net        | current_num_user:  159 | total_users: 5000 | timesheet_count:     5125 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: tyler67@example.net             | current_num_user:  160 | total_users: 5000 | timesheet_count:     5168 | ETA:    6 min | elapsed_time:   70 ms
# Added timesheets for: bentleydylan@example.com        | current_num_user:  161 | total_users: 5000 | timesheet_count:     5191 | ETA:    6 min | elapsed_time:   70 ms
# Added timesheets for: smithjames@example.net          | current_num_user:  162 | total_users: 5000 | timesheet_count:     5204 | ETA:    5 min | elapsed_time:   68 ms
# Added timesheets for: trujillojoshua@example.com      | current_num_user:  163 | total_users: 5000 | timesheet_count:     5207 | ETA:   13 min | elapsed_time:  157 ms
# Added timesheets for: timothy89@example.org           | current_num_user:  165 | total_users: 5000 | timesheet_count:     5279 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: khughes@example.com             | current_num_user:  166 | total_users: 5000 | timesheet_count:     5296 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: jamesbruce@example.com          | current_num_user:  168 | total_users: 5000 | timesheet_count:     5342 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: raven70@example.com             | current_num_user:  170 | total_users: 5000 | timesheet_count:     5423 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: kimangela@example.com           | current_num_user:  171 | total_users: 5000 | timesheet_count:     5423 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: hubbardmanuel@example.com       | current_num_user:  173 | total_users: 5000 | timesheet_count:     5474 | ETA:    6 min | elapsed_time:   70 ms
# Added timesheets for: seth64@example.com              | current_num_user:  174 | total_users: 5000 | timesheet_count:     5580 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: osbornelizabeth@example.net     | current_num_user:  175 | total_users: 5000 | timesheet_count:     5683 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: fbeck@example.net               | current_num_user:  176 | total_users: 5000 | timesheet_count:     5702 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: xmontgomery@example.org         | current_num_user:  177 | total_users: 5000 | timesheet_count:     5717 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: usmith@example.org              | current_num_user:  178 | total_users: 5000 | timesheet_count:     5740 | ETA:    6 min | elapsed_time:   76 ms
# Added timesheets for: seanfrench@example.net          | current_num_user:  179 | total_users: 5000 | timesheet_count:     5784 | ETA:    6 min | elapsed_time:   69 ms
# Added timesheets for: obishop@example.net             | current_num_user:  180 | total_users: 5000 | timesheet_count:     5784 | ETA:    5 min | elapsed_time:   62 ms
# Added timesheets for: kblankenship@example.org        | current_num_user:  181 | total_users: 5000 | timesheet_count:     5811 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: mike37@example.org              | current_num_user:  183 | total_users: 5000 | timesheet_count:     5834 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: aaronriley@example.com          | current_num_user:  184 | total_users: 5000 | timesheet_count:     5851 | ETA:   13 min | elapsed_time:  158 ms
# Added timesheets for: johnhoward@example.net          | current_num_user:  185 | total_users: 5000 | timesheet_count:     5956 | ETA:    7 min | elapsed_time:   81 ms
# Added timesheets for: mark46@example.org              | current_num_user:  187 | total_users: 5000 | timesheet_count:     5991 | ETA:    5 min | elapsed_time:   68 ms
# Added timesheets for: edavidson@example.org           | current_num_user:  188 | total_users: 5000 | timesheet_count:     6020 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: gonzalezharold@example.com      | current_num_user:  189 | total_users: 5000 | timesheet_count:     6050 | ETA:    6 min | elapsed_time:   69 ms
# Added timesheets for: neverett@example.net            | current_num_user:  190 | total_users: 5000 | timesheet_count:     6144 | ETA:    6 min | elapsed_time:   72 ms
# Added timesheets for: stevenmoyer@example.net         | current_num_user:  192 | total_users: 5000 | timesheet_count:     6180 | ETA:    6 min | elapsed_time:   70 ms
# Added timesheets for: cooklance@example.net           | current_num_user:  193 | total_users: 5000 | timesheet_count:     6262 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: ecurry@example.com              | current_num_user:  194 | total_users: 5000 | timesheet_count:     6329 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: martinpamela@example.com        | current_num_user:  195 | total_users: 5000 | timesheet_count:     6388 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: courtneyrogers@example.org      | current_num_user:  196 | total_users: 5000 | timesheet_count:     6474 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: rebeccawatson@example.com       | current_num_user:  197 | total_users: 5000 | timesheet_count:     6479 | ETA:    5 min | elapsed_time:   68 ms
# Added timesheets for: angela95@example.com            | current_num_user:  198 | total_users: 5000 | timesheet_count:     6479 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: harperanthony@example.com       | current_num_user:  200 | total_users: 5000 | timesheet_count:     6562 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: qbender@example.net             | current_num_user:  202 | total_users: 5000 | timesheet_count:     6584 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: xcampbell@example.org           | current_num_user:  203 | total_users: 5000 | timesheet_count:     6612 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: wthomas@example.com             | current_num_user:  204 | total_users: 5000 | timesheet_count:     6636 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: coreyritter@example.com         | current_num_user:  206 | total_users: 5000 | timesheet_count:     6654 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: emilylee@example.org            | current_num_user:  207 | total_users: 5000 | timesheet_count:     6701 | ETA:    6 min | elapsed_time:   69 ms
# Added timesheets for: jwilson@example.net             | current_num_user:  208 | total_users: 5000 | timesheet_count:     6801 | ETA:    6 min | elapsed_time:   72 ms
# Added timesheets for: angelabradley@example.net       | current_num_user:  209 | total_users: 5000 | timesheet_count:     6822 | ETA:    5 min | elapsed_time:   68 ms
# Added timesheets for: jonathanwright@example.net      | current_num_user:  210 | total_users: 5000 | timesheet_count:     6852 | ETA:   12 min | elapsed_time:  150 ms
# Added timesheets for: nielsendean@example.org         | current_num_user:  211 | total_users: 5000 | timesheet_count:     6867 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: audrey06@example.com            | current_num_user:  212 | total_users: 5000 | timesheet_count:     6867 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: weaverheather@example.com       | current_num_user:  213 | total_users: 5000 | timesheet_count:     6885 | ETA:    6 min | elapsed_time:   69 ms
# Added timesheets for: jessica07@example.com           | current_num_user:  214 | total_users: 5000 | timesheet_count:     6898 | ETA:    5 min | elapsed_time:   69 ms
# Added timesheets for: morenomatthew@example.com       | current_num_user:  215 | total_users: 5000 | timesheet_count:     6924 | ETA:    5 min | elapsed_time:   65 ms
# Added timesheets for: shannonrachel@example.net       | current_num_user:  216 | total_users: 5000 | timesheet_count:     6981 | ETA:    5 min | elapsed_time:   69 ms
# Added timesheets for: vlawson@example.org             | current_num_user:  217 | total_users: 5000 | timesheet_count:     7001 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: michaelwalker@example.org       | current_num_user:  218 | total_users: 5000 | timesheet_count:     7026 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: laurawilliamson@example.com     | current_num_user:  219 | total_users: 5000 | timesheet_count:     7099 | ETA:    6 min | elapsed_time:   69 ms
# Added timesheets for: murphyveronica@example.com      | current_num_user:  220 | total_users: 5000 | timesheet_count:     7142 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: angie79@example.net             | current_num_user:  221 | total_users: 5000 | timesheet_count:     7142 | ETA:    6 min | elapsed_time:   69 ms
# Added timesheets for: hblackburn@example.org          | current_num_user:  222 | total_users: 5000 | timesheet_count:     7183 | ETA:    6 min | elapsed_time:   72 ms
# Added timesheets for: matthewmartin@example.org       | current_num_user:  223 | total_users: 5000 | timesheet_count:     7233 | ETA:    6 min | elapsed_time:   71 ms
# Added timesheets for: grivera@example.com             | current_num_user:  224 | total_users: 5000 | timesheet_count:     7240 | ETA:    5 min | elapsed_time:   65 ms
# Added timesheets for: kevin46@example.com             | current_num_user:  225 | total_users: 5000 | timesheet_count:     7248 | ETA:    5 min | elapsed_time:   65 ms
# Added timesheets for: patricia27@example.com          | current_num_user:  226 | total_users: 5000 | timesheet_count:     7269 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: sanchezlisa@example.net         | current_num_user:  227 | total_users: 5000 | timesheet_count:     7294 | ETA:   13 min | elapsed_time:  158 ms
# Added timesheets for: vasquezkayla@example.org        | current_num_user:  228 | total_users: 5000 | timesheet_count:     7370 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: yyu@example.net                 | current_num_user:  229 | total_users: 5000 | timesheet_count:     7413 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: anna72@example.com              | current_num_user:  230 | total_users: 5000 | timesheet_count:     7440 | ETA:    5 min | elapsed_time:   68 ms
# Added timesheets for: aaronmartin@example.net         | current_num_user:  231 | total_users: 5000 | timesheet_count:     7441 | ETA:    6 min | elapsed_time:   69 ms
# Added timesheets for: matthewbanks@example.com        | current_num_user:  232 | total_users: 5000 | timesheet_count:     7531 | ETA:    6 min | elapsed_time:   72 ms
# Added timesheets for: broberts@example.net            | current_num_user:  233 | total_users: 5000 | timesheet_count:     7594 | ETA:    6 min | elapsed_time:   71 ms
# Added timesheets for: kurt72@example.com              | current_num_user:  234 | total_users: 5000 | timesheet_count:     7653 | ETA:    5 min | elapsed_time:   68 ms
# Added timesheets for: gmyers@example.com              | current_num_user:  235 | total_users: 5000 | timesheet_count:     7684 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: bonnie55@example.com            | current_num_user:  236 | total_users: 5000 | timesheet_count:     7684 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: brenda70@example.net            | current_num_user:  237 | total_users: 5000 | timesheet_count:     7706 | ETA:    5 min | elapsed_time:   69 ms
# Added timesheets for: taylorwhitney@example.org       | current_num_user:  238 | total_users: 5000 | timesheet_count:     7710 | ETA:    5 min | elapsed_time:   64 ms
# Added timesheets for: pettymarisa@example.com         | current_num_user:  239 | total_users: 5000 | timesheet_count:     7718 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: beardkelly@example.com          | current_num_user:  240 | total_users: 5000 | timesheet_count:     7828 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: moodynancy@example.com          | current_num_user:  242 | total_users: 5000 | timesheet_count:     7851 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: cjones@example.com              | current_num_user:  244 | total_users: 5000 | timesheet_count:     7881 | ETA:    5 min | elapsed_time:   68 ms
# Added timesheets for: zcline@example.org              | current_num_user:  245 | total_users: 5000 | timesheet_count:     7881 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: daltoncarlson@example.org       | current_num_user:  246 | total_users: 5000 | timesheet_count:     7887 | ETA:    5 min | elapsed_time:   69 ms
# Added timesheets for: heathmelanie@example.org        | current_num_user:  247 | total_users: 5000 | timesheet_count:     7905 | ETA:    5 min | elapsed_time:   64 ms
# Added timesheets for: mmayer@example.net              | current_num_user:  248 | total_users: 5000 | timesheet_count:     8026 | ETA:   13 min | elapsed_time:  165 ms
# Added timesheets for: sergio41@example.net            | current_num_user:  249 | total_users: 5000 | timesheet_count:     8028 | ETA:    5 min | elapsed_time:   69 ms
# Added timesheets for: johnsondeanna@example.com       | current_num_user:  250 | total_users: 5000 | timesheet_count:     8034 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: maddenkelly@example.org         | current_num_user:  252 | total_users: 5000 | timesheet_count:     8038 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: kathleen88@example.org          | current_num_user:  253 | total_users: 5000 | timesheet_count:     8058 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: mary65@example.org              | current_num_user:  254 | total_users: 5000 | timesheet_count:     8109 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: adamspatrick@example.com        | current_num_user:  255 | total_users: 5000 | timesheet_count:     8231 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: aaron50@example.net             | current_num_user:  256 | total_users: 5000 | timesheet_count:     8231 | ETA:    5 min | elapsed_time:   69 ms
# Added timesheets for: caitlinhicks@example.net        | current_num_user:  257 | total_users: 5000 | timesheet_count:     8260 | ETA:    5 min | elapsed_time:   64 ms
# Added timesheets for: jennifer73@example.net          | current_num_user:  258 | total_users: 5000 | timesheet_count:     8334 | ETA:    6 min | elapsed_time:   76 ms
# Added timesheets for: michelleprice@example.com       | current_num_user:  259 | total_users: 5000 | timesheet_count:     8334 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: ehill@example.org               | current_num_user:  260 | total_users: 5000 | timesheet_count:     8375 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: deannagreene@example.org        | current_num_user:  261 | total_users: 5000 | timesheet_count:     8433 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: rwilliams@example.com           | current_num_user:  262 | total_users: 5000 | timesheet_count:     8434 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: jeanweaver@example.net          | current_num_user:  263 | total_users: 5000 | timesheet_count:     8472 | ETA:    5 min | elapsed_time:   69 ms
# Added timesheets for: vaguilar@example.org            | current_num_user:  264 | total_users: 5000 | timesheet_count:     8488 | ETA:   12 min | elapsed_time:  158 ms
# Added timesheets for: monica39@example.org            | current_num_user:  265 | total_users: 5000 | timesheet_count:     8488 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: sgibson@example.net             | current_num_user:  266 | total_users: 5000 | timesheet_count:     8489 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: zestrada@example.net            | current_num_user:  267 | total_users: 5000 | timesheet_count:     8517 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: fieldsmark@example.net          | current_num_user:  268 | total_users: 5000 | timesheet_count:     8541 | ETA:    6 min | elapsed_time:   77 ms
# Added timesheets for: caitlinparker@example.net       | current_num_user:  269 | total_users: 5000 | timesheet_count:     8625 | ETA:    6 min | elapsed_time:   72 ms
# Added timesheets for: markmata@example.org            | current_num_user:  271 | total_users: 5000 | timesheet_count:     8631 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: jessicafarley@example.net       | current_num_user:  272 | total_users: 5000 | timesheet_count:     8684 | ETA:    5 min | elapsed_time:   69 ms
# Added timesheets for: maddoxmartha@example.com        | current_num_user:  273 | total_users: 5000 | timesheet_count:     8710 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: oross@example.net               | current_num_user:  274 | total_users: 5000 | timesheet_count:     8737 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: joyperkins@example.org          | current_num_user:  275 | total_users: 5000 | timesheet_count:     8749 | ETA:    6 min | elapsed_time:   71 ms
# Added timesheets for: howardwilliam@example.net       | current_num_user:  276 | total_users: 5000 | timesheet_count:     8755 | ETA:    6 min | elapsed_time:   77 ms
# Added timesheets for: maryparsons@example.org         | current_num_user:  277 | total_users: 5000 | timesheet_count:     8788 | ETA:    5 min | elapsed_time:   69 ms
# Added timesheets for: mcmillanmichele@example.net     | current_num_user:  278 | total_users: 5000 | timesheet_count:     8788 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: hschwartz@example.com           | current_num_user:  279 | total_users: 5000 | timesheet_count:     8791 | ETA:    5 min | elapsed_time:   69 ms
# Added timesheets for: dwayne09@example.com            | current_num_user:  280 | total_users: 5000 | timesheet_count:     8864 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: shelia81@example.net            | current_num_user:  281 | total_users: 5000 | timesheet_count:     8877 | ETA:    5 min | elapsed_time:   63 ms
# Added timesheets for: norrissharon@example.com        | current_num_user:  283 | total_users: 5000 | timesheet_count:     8901 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: stevendougherty@example.net     | current_num_user:  284 | total_users: 5000 | timesheet_count:     8907 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: csanchez@example.org            | current_num_user:  285 | total_users: 5000 | timesheet_count:     9014 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: msparks@example.com             | current_num_user:  286 | total_users: 5000 | timesheet_count:     9102 | ETA:   13 min | elapsed_time:  162 ms
# Added timesheets for: jessica62@example.org           | current_num_user:  287 | total_users: 5000 | timesheet_count:     9119 | ETA:    5 min | elapsed_time:   69 ms
# Added timesheets for: rherman@example.com             | current_num_user:  288 | total_users: 5000 | timesheet_count:     9189 | ETA:    6 min | elapsed_time:   71 ms
# Added timesheets for: jacqueline25@example.net        | current_num_user:  290 | total_users: 5000 | timesheet_count:     9200 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: haysandrew@example.com          | current_num_user:  291 | total_users: 5000 | timesheet_count:     9205 | ETA:    6 min | elapsed_time:   76 ms
# Added timesheets for: scott36@example.com             | current_num_user:  292 | total_users: 5000 | timesheet_count:     9205 | ETA:    5 min | elapsed_time:   68 ms
# Added timesheets for: ernest21@example.net            | current_num_user:  293 | total_users: 5000 | timesheet_count:     9298 | ETA:    6 min | elapsed_time:   71 ms
# Added timesheets for: lesterrobin@example.org         | current_num_user:  294 | total_users: 5000 | timesheet_count:     9374 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: mark35@example.net              | current_num_user:  295 | total_users: 5000 | timesheet_count:     9390 | ETA:    5 min | elapsed_time:   69 ms
# Added timesheets for: ryan93@example.net              | current_num_user:  296 | total_users: 5000 | timesheet_count:     9458 | ETA:    6 min | elapsed_time:   73 ms
# Added timesheets for: dylan93@example.net             | current_num_user:  297 | total_users: 5000 | timesheet_count:     9481 | ETA:    5 min | elapsed_time:   68 ms
# Added timesheets for: lmarshall@example.net           | current_num_user:  298 | total_users: 5000 | timesheet_count:     9484 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: zlewis@example.com              | current_num_user:  299 | total_users: 5000 | timesheet_count:     9530 | ETA:    6 min | elapsed_time:   71 ms
# Added timesheets for: odonnellann@example.org         | current_num_user:  300 | total_users: 5000 | timesheet_count:     9530 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: chelseasolomon@example.net      | current_num_user:  301 | total_users: 5000 | timesheet_count:     9577 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: jessicalandry@example.com       | current_num_user:  302 | total_users: 5000 | timesheet_count:     9613 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: williamsjeffrey@example.org     | current_num_user:  303 | total_users: 5000 | timesheet_count:     9647 | ETA:    5 min | elapsed_time:   68 ms
# Added timesheets for: kelly46@example.org             | current_num_user:  304 | total_users: 5000 | timesheet_count:     9677 | ETA:   12 min | elapsed_time:  158 ms
# Added timesheets for: jessicaguzman@example.org       | current_num_user:  305 | total_users: 5000 | timesheet_count:     9712 | ETA:    5 min | elapsed_time:   69 ms
# Added timesheets for: shannonfitzgerald@example.org   | current_num_user:  306 | total_users: 5000 | timesheet_count:     9737 | ETA:    6 min | elapsed_time:   72 ms
# Added timesheets for: brose@example.org               | current_num_user:  307 | total_users: 5000 | timesheet_count:     9737 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: allison08@example.net           | current_num_user:  308 | total_users: 5000 | timesheet_count:     9780 | ETA:    6 min | elapsed_time:   72 ms
# Added timesheets for: nbranch@example.org             | current_num_user:  309 | total_users: 5000 | timesheet_count:     9819 | ETA:    5 min | elapsed_time:   69 ms
# Added timesheets for: emilythomas@example.com         | current_num_user:  310 | total_users: 5000 | timesheet_count:     9906 | ETA:    6 min | elapsed_time:   74 ms
# Added timesheets for: bgalloway@example.com           | current_num_user:  311 | total_users: 5000 | timesheet_count:     9999 | ETA:    5 min | elapsed_time:   69 ms
# Added timesheets for: nking@example.org               | current_num_user:  312 | total_users: 5000 | timesheet_count:    10068 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: bennettjasmine@example.net      | current_num_user:  313 | total_users: 5000 | timesheet_count:    10070 | ETA:    5 min | elapsed_time:   65 ms
# Added timesheets for: joanngarner@example.net         | current_num_user:  314 | total_users: 5000 | timesheet_count:    10099 | ETA:    6 min | elapsed_time:   75 ms
# Added timesheets for: jamesjones@example.com          | current_num_user:  315 | total_users: 5000 | timesheet_count:    10167 | ETA:    5 min | elapsed_time:   67 ms
# Added timesheets for: matthewking@example.org         | current_num_user:  316 | total_users: 5000 | timesheet_count:    10167 | ETA:    5 min | elapsed_time:   66 ms
# Added timesheets for: jonesmichael@example.net        | current_num_user:  317 | total_users: 5000 | timesheet_count:    10167 | ETA:    6 min | elapsed_time:   71 ms
# ...
# Added timesheets for: brownmichele@example.com        | current_num_user: 4914 | total_users: 5000 | timesheet_count:   168039 | ETA:    0 min | elapsed_time:   68 ms
# Added timesheets for: jenniferchung@example.net       | current_num_user: 4915 | total_users: 5000 | timesheet_count:   168048 | ETA:    0 min | elapsed_time:   74 ms
# Added timesheets for: cathyortega@example.net         | current_num_user: 4917 | total_users: 5000 | timesheet_count:   168058 | ETA:    0 min | elapsed_time:   67 ms
# Added timesheets for: rebecca38@example.net           | current_num_user: 4918 | total_users: 5000 | timesheet_count:   168087 | ETA:    0 min | elapsed_time:   71 ms
# Added timesheets for: vroberts@example.org            | current_num_user: 4919 | total_users: 5000 | timesheet_count:   168182 | ETA:    0 min | elapsed_time:   70 ms
# Added timesheets for: johnsmary@example.com           | current_num_user: 4920 | total_users: 5000 | timesheet_count:   168195 | ETA:    0 min | elapsed_time:   75 ms
# Added timesheets for: richard86@example.org           | current_num_user: 4921 | total_users: 5000 | timesheet_count:   168278 | ETA:    0 min | elapsed_time:   74 ms
# Added timesheets for: andressantos@example.net        | current_num_user: 4922 | total_users: 5000 | timesheet_count:   168305 | ETA:    0 min | elapsed_time:   68 ms
# Added timesheets for: sethsnow@example.org            | current_num_user: 4924 | total_users: 5000 | timesheet_count:   168382 | ETA:    0 min | elapsed_time:   75 ms
# Added timesheets for: bortiz@example.net              | current_num_user: 4925 | total_users: 5000 | timesheet_count:   168393 | ETA:    0 min | elapsed_time:   93 ms
# Added timesheets for: fishercaleb@example.com         | current_num_user: 4926 | total_users: 5000 | timesheet_count:   168454 | ETA:    0 min | elapsed_time:   64 ms
# Added timesheets for: ndrake@example.com              | current_num_user: 4927 | total_users: 5000 | timesheet_count:   168532 | ETA:    0 min | elapsed_time:   77 ms
# Added timesheets for: kgonzales@example.org           | current_num_user: 4928 | total_users: 5000 | timesheet_count:   168535 | ETA:    0 min | elapsed_time:   69 ms
# Added timesheets for: tiffany65@example.net           | current_num_user: 4929 | total_users: 5000 | timesheet_count:   168633 | ETA:    0 min | elapsed_time:   77 ms
# Added timesheets for: sullivanbryan@example.com       | current_num_user: 4930 | total_users: 5000 | timesheet_count:   168633 | ETA:    0 min | elapsed_time:   68 ms
# Added timesheets for: pmartinez@example.com           | current_num_user: 4931 | total_users: 5000 | timesheet_count:   168711 | ETA:    0 min | elapsed_time:  174 ms
# Added timesheets for: whiteholly@example.org          | current_num_user: 4932 | total_users: 5000 | timesheet_count:   168742 | ETA:    0 min | elapsed_time:   68 ms
# Added timesheets for: jeremymcbride@example.net       | current_num_user: 4933 | total_users: 5000 | timesheet_count:   168755 | ETA:    0 min | elapsed_time:   67 ms
# Added timesheets for: bowens@example.com              | current_num_user: 4934 | total_users: 5000 | timesheet_count:   168777 | ETA:    0 min | elapsed_time:   76 ms
# Added timesheets for: gregoryrobert@example.com       | current_num_user: 4935 | total_users: 5000 | timesheet_count:   168825 | ETA:    0 min | elapsed_time:   70 ms
# Added timesheets for: etorres@example.org             | current_num_user: 4936 | total_users: 5000 | timesheet_count:   168905 | ETA:    0 min | elapsed_time:   73 ms
# Added timesheets for: andersonmarissa@example.org     | current_num_user: 4937 | total_users: 5000 | timesheet_count:   168993 | ETA:    0 min | elapsed_time:   71 ms
# Added timesheets for: pchavez@example.org             | current_num_user: 4938 | total_users: 5000 | timesheet_count:   169054 | ETA:    0 min | elapsed_time:   74 ms
# Added timesheets for: trevor88@example.com            | current_num_user: 4939 | total_users: 5000 | timesheet_count:   169076 | ETA:    0 min | elapsed_time:   75 ms
# Added timesheets for: dross@example.org               | current_num_user: 4940 | total_users: 5000 | timesheet_count:   169114 | ETA:    0 min | elapsed_time:   76 ms
# Added timesheets for: joshuacowan@example.com         | current_num_user: 4941 | total_users: 5000 | timesheet_count:   169192 | ETA:    0 min | elapsed_time:   73 ms
# Added timesheets for: sparksnicholas@example.net      | current_num_user: 4942 | total_users: 5000 | timesheet_count:   169258 | ETA:    0 min | elapsed_time:   69 ms
# Added timesheets for: nancy92@example.net             | current_num_user: 4943 | total_users: 5000 | timesheet_count:   169377 | ETA:    0 min | elapsed_time:   83 ms
# Added timesheets for: jshaw@example.com               | current_num_user: 4944 | total_users: 5000 | timesheet_count:   169398 | ETA:    0 min | elapsed_time:   67 ms
# Added timesheets for: nelsonwalter@example.org        | current_num_user: 4945 | total_users: 5000 | timesheet_count:   169413 | ETA:    0 min | elapsed_time:   76 ms
# Added timesheets for: andrew69@example.org            | current_num_user: 4946 | total_users: 5000 | timesheet_count:   169423 | ETA:    0 min | elapsed_time:   67 ms
# Added timesheets for: dsmith@example.net              | current_num_user: 4947 | total_users: 5000 | timesheet_count:   169474 | ETA:    0 min | elapsed_time:   74 ms
# Added timesheets for: joseph28@example.com            | current_num_user: 4948 | total_users: 5000 | timesheet_count:   169499 | ETA:    0 min | elapsed_time:   65 ms
# Added timesheets for: mreynolds@example.net           | current_num_user: 4949 | total_users: 5000 | timesheet_count:   169531 | ETA:    0 min | elapsed_time:   75 ms
# Added timesheets for: hernandezmelissa@example.com    | current_num_user: 4951 | total_users: 5000 | timesheet_count:   169531 | ETA:    0 min | elapsed_time:  162 ms
# Added timesheets for: michaelgardner@example.org      | current_num_user: 4952 | total_users: 5000 | timesheet_count:   169554 | ETA:    0 min | elapsed_time:   71 ms
# Added timesheets for: estewart@example.org            | current_num_user: 4953 | total_users: 5000 | timesheet_count:   169579 | ETA:    0 min | elapsed_time:   75 ms
# Added timesheets for: zweber@example.net              | current_num_user: 4954 | total_users: 5000 | timesheet_count:   169634 | ETA:    0 min | elapsed_time:   71 ms
# Added timesheets for: sean21@example.org              | current_num_user: 4955 | total_users: 5000 | timesheet_count:   169760 | ETA:    0 min | elapsed_time:   71 ms
# Added timesheets for: price@example.org               | current_num_user: 4956 | total_users: 5000 | timesheet_count:   169804 | ETA:    0 min | elapsed_time:   75 ms
# Added timesheets for: david74@example.com             | current_num_user: 4957 | total_users: 5000 | timesheet_count:   169822 | ETA:    0 min | elapsed_time:   68 ms
# Added timesheets for: ngray@example.net               | current_num_user: 4958 | total_users: 5000 | timesheet_count:   169885 | ETA:    0 min | elapsed_time:   73 ms
# Added timesheets for: pwade@example.org               | current_num_user: 4959 | total_users: 5000 | timesheet_count:   169893 | ETA:    0 min | elapsed_time:   83 ms
# Added timesheets for: andre61@example.com             | current_num_user: 4960 | total_users: 5000 | timesheet_count:   169960 | ETA:    0 min | elapsed_time:   75 ms
# Added timesheets for: gatesbarbara@example.com        | current_num_user: 4961 | total_users: 5000 | timesheet_count:   169986 | ETA:    0 min | elapsed_time:   77 ms
# Added timesheets for: johncortez@example.com          | current_num_user: 4962 | total_users: 5000 | timesheet_count:   170015 | ETA:    0 min | elapsed_time:   65 ms
# Added timesheets for: jeffrey69@example.com           | current_num_user: 4963 | total_users: 5000 | timesheet_count:   170072 | ETA:    0 min | elapsed_time:   83 ms
# Added timesheets for: jjohnson@example.com            | current_num_user: 4964 | total_users: 5000 | timesheet_count:   170079 | ETA:    0 min | elapsed_time:   68 ms
# Added timesheets for: millerchristopher@example.net   | current_num_user: 4965 | total_users: 5000 | timesheet_count:   170128 | ETA:    0 min | elapsed_time:   71 ms
# Added timesheets for: tannertammy@example.com         | current_num_user: 4967 | total_users: 5000 | timesheet_count:   170139 | ETA:    0 min | elapsed_time:  176 ms
# Added timesheets for: michaelkent@example.net         | current_num_user: 4968 | total_users: 5000 | timesheet_count:   170158 | ETA:    0 min | elapsed_time:   74 ms
# Added timesheets for: ghill@example.com               | current_num_user: 4969 | total_users: 5000 | timesheet_count:   170179 | ETA:    0 min | elapsed_time:   68 ms
# Added timesheets for: gutierrezcolin@example.net      | current_num_user: 4970 | total_users: 5000 | timesheet_count:   170192 | ETA:    0 min | elapsed_time:   72 ms
# Added timesheets for: callahanjustin@example.net      | current_num_user: 4971 | total_users: 5000 | timesheet_count:   170233 | ETA:    0 min | elapsed_time:   76 ms
# Added timesheets for: slutz@example.net               | current_num_user: 4972 | total_users: 5000 | timesheet_count:   170267 | ETA:    0 min | elapsed_time:   72 ms
# Added timesheets for: joshua03@example.com            | current_num_user: 4973 | total_users: 5000 | timesheet_count:   170267 | ETA:    0 min | elapsed_time:   61 ms
# Added timesheets for: mary43@example.net              | current_num_user: 4974 | total_users: 5000 | timesheet_count:   170271 | ETA:    0 min | elapsed_time:   68 ms
# Added timesheets for: frichards@example.net           | current_num_user: 4975 | total_users: 5000 | timesheet_count:   170272 | ETA:    0 min | elapsed_time:   69 ms
# Added timesheets for: jvillanueva@example.net         | current_num_user: 4976 | total_users: 5000 | timesheet_count:   170338 | ETA:    0 min | elapsed_time:   72 ms
# Added timesheets for: sheilagonzalez@example.net      | current_num_user: 4977 | total_users: 5000 | timesheet_count:   170338 | ETA:    0 min | elapsed_time:   72 ms
# Added timesheets for: baileysmith@example.org         | current_num_user: 4978 | total_users: 5000 | timesheet_count:   170354 | ETA:    0 min | elapsed_time:   69 ms
# Added timesheets for: jfernandez@example.org          | current_num_user: 4979 | total_users: 5000 | timesheet_count:   170358 | ETA:    0 min | elapsed_time:   69 ms
# Added timesheets for: perezjasmine@example.org        | current_num_user: 4980 | total_users: 5000 | timesheet_count:   170370 | ETA:    0 min | elapsed_time:   69 ms
# Added timesheets for: leblancdaniel@example.org       | current_num_user: 4981 | total_users: 5000 | timesheet_count:   170383 | ETA:    0 min | elapsed_time:   63 ms
# Added timesheets for: fordnathan@example.com          | current_num_user: 4982 | total_users: 5000 | timesheet_count:   170423 | ETA:    0 min | elapsed_time:   75 ms
# Added timesheets for: abigail46@example.net           | current_num_user: 4983 | total_users: 5000 | timesheet_count:   170430 | ETA:    0 min | elapsed_time:   67 ms
# Added timesheets for: amandasolomon@example.org       | current_num_user: 4984 | total_users: 5000 | timesheet_count:   170452 | ETA:    0 min | elapsed_time:   73 ms
# Added timesheets for: vbrewer@example.net             | current_num_user: 4985 | total_users: 5000 | timesheet_count:   170485 | ETA:    0 min | elapsed_time:   67 ms
# Added timesheets for: teresatran@example.com          | current_num_user: 4986 | total_users: 5000 | timesheet_count:   170488 | ETA:    0 min | elapsed_time:   75 ms
# Added timesheets for: todd84@example.net              | current_num_user: 4988 | total_users: 5000 | timesheet_count:   170545 | ETA:    0 min | elapsed_time:  172 ms
# Added timesheets for: gregoryfernandez@example.net    | current_num_user: 4989 | total_users: 5000 | timesheet_count:   170567 | ETA:    0 min | elapsed_time:   69 ms
# Added timesheets for: brian45@example.net             | current_num_user: 4990 | total_users: 5000 | timesheet_count:   170570 | ETA:    0 min | elapsed_time:   68 ms
# Added timesheets for: gabrieldiaz@example.org         | current_num_user: 4992 | total_users: 5000 | timesheet_count:   170621 | ETA:    0 min | elapsed_time:   74 ms
# Added timesheets for: harveyjohn@example.net          | current_num_user: 4993 | total_users: 5000 | timesheet_count:   170624 | ETA:    0 min | elapsed_time:   72 ms
# Added timesheets for: rubiosara@example.net           | current_num_user: 4994 | total_users: 5000 | timesheet_count:   170675 | ETA:    0 min | elapsed_time:   70 ms
# Added timesheets for: mritter@example.net             | current_num_user: 4995 | total_users: 5000 | timesheet_count:   170731 | ETA:    0 min | elapsed_time:   76 ms
# Added timesheets for: emily52@example.org             | current_num_user: 4996 | total_users: 5000 | timesheet_count:   170794 | ETA:    0 min | elapsed_time:   74 ms
# Added timesheets for: julia63@example.org             | current_num_user: 4997 | total_users: 5000 | timesheet_count:   170808 | ETA:    0 min | elapsed_time:   67 ms
# Added timesheets for: wallerheather@example.com       | current_num_user: 4998 | total_users: 5000 | timesheet_count:   170808 | ETA:    0 min | elapsed_time:   70 ms
# Added timesheets for: rodneyfischer@example.org       | current_num_user: 4999 | total_users: 5000 | timesheet_count:   170858 | ETA:    0 min | elapsed_time:   72 ms
#                         userEmail                         projectSelected  \
# 0             wbriggs@example.net                     Chaney Inc Solution
# 1             wbriggs@example.net      Wilson, Jackson and Green Solution
# 2             wbriggs@example.net      Wilson, Jackson and Green Solution
# 3             wbriggs@example.net  Gonzales, Martin and Carter Initiative
# 4             wbriggs@example.net  Gonzales, Martin and Carter Initiative
# ...                           ...                                     ...
# 170853  rodneyfischer@example.org                    Olson-Craig Solution
# 170854  rodneyfischer@example.org                    Olson-Craig Solution
# 170855  rodneyfischer@example.org                   Saunders LLC Solution
# 170856  rodneyfischer@example.org                 Briggs-Jennings Project
# 170857  rodneyfischer@example.org                 Briggs-Jennings Project
#
#          dateStart     dateEnd taskSelected             commentAdded   d0  \
# 0       04-09-2022  10-09-2022         None                     None  NaN
# 1       04-09-2022  10-09-2022         None  Excited to get started!  1.0
# 2       04-09-2022  10-09-2022         None  Excited to get started!  1.0
# 3       04-09-2022  10-09-2022         None  Excited to get started!  NaN
# 4       04-09-2022  10-09-2022         None  Excited to get started!  NaN
# ...            ...         ...          ...                      ...  ...
# 170853  25-12-2022  31-12-2022         None         Ready to dive in  2.0
# 170854  25-12-2022  31-12-2022         None         Ready to dive in  2.0
# 170855  10-12-2023  16-12-2023         None                     None  NaN
# 170856  22-05-2022  28-05-2022         None                     None  1.0
# 170857  22-05-2022  28-05-2022         None                     None  1.0
#
#          d1   d2   d3   d4    d5   d6    activityName
# 0       1.0  1.0  2.0  NaN   2.0  1.0  Sales Activity
# 1       1.0  NaN  1.0  1.0   NaN  NaN    BAU Activity
# 2       1.0  NaN  1.0  1.0   NaN  NaN  Sales Activity
# 3       1.0  2.0  NaN  2.0   2.0  NaN  Sales Activity
# 4       1.0  2.0  NaN  2.0   2.0  NaN    BAU Activity
# ...     ...  ...  ...  ...   ...  ...             ...
# 170853  2.0  8.0  1.0  7.0   NaN  NaN  Sales Activity
# 170854  2.0  8.0  1.0  7.0   NaN  NaN    BAU Activity
# 170855  1.0  9.0  NaN  6.0   4.0  1.0  Sales Activity
# 170856  3.0  NaN  NaN  NaN  10.0  NaN    BAU Activity
# 170857  3.0  NaN  NaN  NaN  10.0  NaN  Sales Activity
#
# [170858 rows x 14 columns]

# %%
def generateFeedbackAnswers():

    text_answer_choices = ['Excellent', 'Good', 'Average', 'Fair', 'Poor']

    project_names = []
    feedback_question_names = []
    checked_answers = []
    text_answers = []
    date_starts = []
    date_ends = []
    user_emails = []

    for _ in range(num_feedback_answers):

        random_projectsToFeedbackQuestions = projectsToFeedbackQuestions_df.sample()
        project_name = random_projectsToFeedbackQuestions['projectName'].iloc[0]
        feedback_question_name = random_projectsToFeedbackQuestions['questionName'].iloc[0]

        corresponding_random_timesheet = timesheets_df[timesheets_df['projectSelected'] == project_name].sample()
        date_start = corresponding_random_timesheet['dateStart'].iloc[0]
        date_end = corresponding_random_timesheet['dateEnd'].iloc[0]
        user_email = corresponding_random_timesheet['userEmail'].iloc[0]

        checked_answer = random.randint(1, 5) if random.random() > 0.2 else None
        text_answer = random.choice(text_answer_choices) if random.random() > 0.8 else None

        project_names.append(project_name)
        feedback_question_names.append(feedback_question_name)
        date_starts.append(date_start)
        date_ends.append(date_end)
        user_emails.append(user_email)
        checked_answers.append(checked_answer)
        text_answers.append(text_answer)

    data = {
        'projectName': project_names,
        'feedbackQuestionName': feedback_question_names,
        'dateStart': date_starts,
        'dateEnd': date_ends,
        'userEmail': user_emails,
        'checkedAnswer': checked_answers,
        'textAnswer': text_answers
    }

    return data

feedbackAnswers_df = pd.DataFrame(generateFeedbackAnswers())
feedbackAnswers_df
# Out:
#                              projectName  \
# 0     Castillo, Frey and Stewart Project
# 1            Wheeler and Sons Initiative
# 2        Jones, Meyer and Smith Solution
# 3              Barnett-Harris Initiative
# 4                      Green Ltd Project
# ...                                  ...
# 7995                    Ward Ltd Project
# 7996              Ross and Sons Solution
# 7997            Allison and Sons Project
# 7998   Roberts, Brown and Lee Initiative
# 7999         Wheeler and Sons Initiative
#
#                                    feedbackQuestionName   dateStart  \
# 0     How satisfied are you with the level of transp...  09-07-2023
# 1     How satisfied are you with the project deliver...  26-11-2023
# 2     Did the project meet your expectations? Please...  04-09-2022
# 3     Rate the accuracy of the project budget estima...  27-11-2022
# 4     Were the project resources allocated efficient...  01-05-2022
# ...                                                 ...         ...
# 7995  Were the project resources allocated efficient...  01-10-2023
# 7996  Rate the accuracy of the project budget estima...  31-07-2022
# 7997  How would you rate the quality of work deliver...  06-11-2022
# 7998  Did the project meet your expectations? Please...  09-10-2022
# 7999  How satisfied are you with the level of collab...  29-01-2023
#
#          dateEnd                       userEmail  checkedAnswer textAnswer
# 0     15-07-2023      jonathonorozco@example.org            3.0       None
# 1     02-12-2023      lucasmiddleton@example.org            3.0       Fair
# 2     10-09-2022       caitlinparker@example.net            NaN       None
# 3     03-12-2022        lblankenship@example.com            3.0       None
# 4     07-05-2022  walterschristopher@example.org            NaN       None
# ...          ...                             ...            ...        ...
# 7995  07-10-2023             shudson@example.org            5.0       None
# 7996  06-08-2022           matthew56@example.net            3.0       Good
# 7997  12-11-2022            brianlee@example.org            4.0       None
# 7998  15-10-2022              rsmith@example.com            2.0       None
# 7999  04-02-2023         ashleejones@example.org            2.0       None
#
# [8000 rows x 7 columns]

# %%
if not os.path.exists('csvs'):
    os.makedirs('csvs')

users_df.to_csv('csvs/users.csv', index=False)
project_df.to_csv('csvs/projects.csv', index=False)
feedbackQuestion_df.to_csv('csvs/feedbackQuestions.csv', index=False)
projectsToUsers_df.to_csv('csvs/projectsToUsers.csv', index=False)
projectsToFeedbackQuestions_df.to_csv('csvs/projectsToFeedbackQuestions.csv', index=False)
timesheets_df.to_csv('csvs/timesheets.csv', index=False)
feedbackAnswers_df.to_csv('csvs/feedbackAnswers.csv', index=False)
